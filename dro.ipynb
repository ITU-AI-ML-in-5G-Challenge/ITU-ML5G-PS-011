# %%
import json
import random 
import datetime

# %%
# This class represent a graph
class Graph:
    # Initialize the class
    def __init__(self, graph_dict=None, directed=True):
        self.graph_dict = graph_dict or {}
        self.directed = directed
        if not directed:
            self.make_undirected()
    # Create an undirected graph by adding symmetric edges
    def make_undirected(self):
        for a in list(self.graph_dict.keys()):
            for (b, dist) in self.graph_dict[a].items():
                self.graph_dict.setdefault(b, {})[a] = dist
    # Add a link from A and B of given distance, and also add the inverse link if the graph is undirected
    def connect(self, A, B, distance=1):
        self.graph_dict.setdefault(A, {})[B] = distance
        if not self.directed:
            self.graph_dict.setdefault(B, {})[A] = distance
#         print('graph dict: {}'.format(self.graph_dict))
    # Get neighbors or a neighbor
    def get(self, a, b=None):
#         print('graph dict: {}'.format(self.graph_dict))
        links = self.graph_dict.setdefault(a, {})
        if b is None:
            return links
#             print('links: {}'.format(links))
        else:
            return links.get(b)
#             print('links: {}'.format(links))
    # Return a list of nodes in the graph
    def nodes(self):
        s1 = set([k for k in self.graph_dict.keys()])
        s2 = set([k2 for v in self.graph_dict.values() for k2, v2 in v.items()])
        nodes = s1.union(s2)
        return list(nodes)
    def print_graph(self):
        print(self.graph_dict)
    
    
# This class represent a node
class Node:
    # Initialize the class
    def __init__(self, name:str, parent:str):
        self.name = name
        self.parent = parent
        self.g = 0 # Distance to start node
        self.h = 0 # Distance to goal node
        self.f = 0 # Total cost
    # Compare nodes
    def __eq__(self, other):
        return self.name == other.name
    # Sort nodes
    def __lt__(self, other):
         return self.f < other.f
    # Print node
    def __repr__(self):
        return ('({0},{1})'.format(self.name, self.f))
    
    
# A* search
def astar_search(graph, heuristics, start, end):
    
    # Create lists for open nodes and closed nodes
    open = []
    closed = []
    # Create a start node and an goal node
    start_node = Node(start, None)
    goal_node = Node(end, None)
    # Add the start node
    open.append(start_node)
    
    # Loop until the open list is empty
    while len(open) > 0:
        # Sort the open list to get the node with the lowest cost first
        open.sort()
        # Get the node with the lowest cost
        current_node = open.pop(0)
#         print('current node: {}'.format(current_node))
        # Add the current node to the closed list
        closed.append(current_node)
        
        # Check if we have reached the goal, return the path
        if current_node == goal_node:
#             path = []
            path = {}
            while current_node != start_node:
#                 path.append(str(current_node.name) + ': ' + str(current_node.g))
                path.setdefault(current_node.name, current_node.g)
                current_node = current_node.parent
#             path.append(str(start_node.name) + ': ' + str(start_node.g))
            path.setdefault(start_node.name, start_node.g)
            # Return reversed path
            return path
#             return path[::-1]
        # Get neighbours
        neighbors = graph.get(current_node.name)
#         print('current_node: {}'.format(current_node.name))
#         print('neighbors: {}'.format(neighbors))
        # Loop neighbors
        for key, value in neighbors.items():
            # Create a neighbor node
            neighbor = Node(key, current_node)
            # Check if the neighbor is in the closed list
            if(neighbor in closed):
                continue
            # Calculate full path cost
            neighbor.g = current_node.g + graph.get(current_node.name, neighbor.name)
            neighbor.h = heuristics.get(neighbor.name)
            neighbor.f = neighbor.g + neighbor.h
            # Check if neighbor is in open list and if it has a lower f value
            if(add_to_open(open, neighbor) == True):
                # Everything is green, add neighbor to open list
                open.append(neighbor)
    # Return None, no path is found
    return None
# Check if a neighbor should be added to open list
def add_to_open(open, neighbor):
    for node in open:
        if (neighbor == node and neighbor.f > node.f):
            return False
    return True

# %%
class Lane:
    # Initialize the class
    def __init__(self, graph_dict=None, directed=True):
        self.graph_dict = graph_dict or {}
        self.directed = directed
        if not directed:
            self.make_undirected()
    # Create an undirected graph by adding symmetric edges
    def make_undirected(self):
        for a in list(self.graph_dict.keys()):
            for (b, dist) in self.graph_dict[a].items():
                self.graph_dict.setdefault(b, {})[a] = dist
    # Add a link from A and B of given distance, and also add the inverse link if the graph is undirected
    def connect(self, A, B, distance=1):
        self.graph_dict.setdefault(A, {})[B] = distance
        if not self.directed:
            self.graph_dict.setdefault(B, {})[A] = distance
#         print('graph dict: {}'.format(self.graph_dict))
    # Get neighbors or a neighbor
    def get(self, a, b=None):
#         print('graph dict: {}'.format(self.graph_dict))
        links = self.graph_dict.setdefault(a, {})
        if b is None:
            return links
#             print('links: {}'.format(links))
        else:
            return links.get(b)
#             print('links: {}'.format(links))
    # Return a list of nodes in the graph
    def nodes(self):
        s1 = set([k for k in self.graph_dict.keys()])
        s2 = set([k2 for v in self.graph_dict.values() for k2, v2 in v.items()])
        nodes = s1.union(s2)
        return list(nodes)
    def print_lanes(self):
        print(self.graph_dict)

# %%
def find_lane(lane, path_list, service_weight):
    
#     print('path list: {}'.format(path_list))
    l = 0
    for i in range(len(path_list)-1):
        a_end = path_list[i]
        z_end = path_list[i+1]
        weights = lane.get(a_end, z_end)
        while weights[l] < service_weight:
            l = l + 1
#             print('lane: {}'.format(l))
            
#     print('lane:{}'.format(l))        
    for i in range(len(path_list)-1):
        a_end = path_list[i]
        z_end = path_list[i+1]
        weights = lane.get(a_end, z_end)
#         print('weights:{}'.format(weights))
        left_weight = weights[l] - service_weight
        weights[l] = left_weight
        lane.connect(a_end, z_end, weights)
        left_weights = lane.get(a_end, z_end)
#         print('left weights:{}'.format(left_weights))
    return l

# %%
def main():
    print(datetime.datetime.now().strftime('%d/%m/%Y %H:%M:%S'))
    g = open('./data/sample_29/graph.json')
    g = json.load(g)
    edges = g['edges']
    nodes = g['nodes']
    
    graph = Graph(directed = False)
    
    lane = Lane(directed = False)
    
    
    for i in range(len(edges)):
        # Set the graph
        a_end = edges[i]['a_end']
        z_end = edges[i]['z_end']
        cost = edges[i]['cost']
        lanes = edges[i]['lane_weights']
#         print('a_end: {}, z_end: {}, cost: {}'.format(a_end, z_end, cost))
        # Create graph connections
        graph.connect(a_end, z_end, cost)
        lane.connect(a_end, z_end, lanes)

    

###### Set the heuristics ######
    heuristics = {}
    for i in range(len(nodes)):
#         heuristics[i] = random.randint(1,9)
        heuristics[i] = 0
#         print('heuristics {}: {}'.format(i, heuristics[i]))
        

    
    
    
    s = open('./data/sample_29/services.json')
    services = json.load(s)
    for i in range(len(services)):
        service = services[i]
        a_end = service['a_end']
        z_end = service['z_end']
        service_weight = service['weight']
        path_dict = astar_search(graph, heuristics, a_end, z_end)
#         print('path: {}'.format(path_dict))
        # reverse the order of the path
        path_list = list(path_dict.keys())[::-1]
        l = find_lane(lane, path_list, service_weight)
        res = {}
        for i in range(len(path_list)):
            node = path_list[i]
            cost = path_dict.get(node)
            res.setdefault(node, cost)
        
        res.setdefault('lane', l)
        print('service: {}'.format(service))
        print('path: {}'.format(res))
        
        
    print(datetime.datetime.now().strftime('%d/%m/%Y %H:%M:%S'))

# %%
# Tell python to run main method
if __name__ == "__main__": 
    main()
# Out:
# 16/09/2021 14:49:42
# service: {'a_end': 138, 'z_end': 206, 'weight': 1}
# path: {138: 0, 171: 1.0, 85: 2.0, 71: 3.0, 206: 4.0, 'lane': 0}
# service: {'a_end': 74, 'z_end': 156, 'weight': 1}
# path: {74: 0, 86: 1.0, 156: 3.0, 'lane': 0}
# service: {'a_end': 7, 'z_end': 159, 'weight': 1}
# path: {7: 0, 115: 1.0, 20: 2.0, 159: 4.0, 'lane': 0}
# service: {'a_end': 167, 'z_end': 211, 'weight': 1}
# path: {167: 0, 182: 2.0, 211: 3.0, 'lane': 0}
# service: {'a_end': 53, 'z_end': 250, 'weight': 1}
# path: {53: 0, 155: 1.0, 241: 2.0, 171: 3.0, 250: 5.0, 'lane': 0}
# service: {'a_end': 65, 'z_end': 12, 'weight': 1}
# path: {65: 0, 146: 1.0, 12: 2.0, 'lane': 0}
# service: {'a_end': 101, 'z_end': 96, 'weight': 1}
# path: {101: 0, 38: 1.0, 15: 3.0, 96: 4.0, 'lane': 0}
# service: {'a_end': 164, 'z_end': 34, 'weight': 1}
# path: {164: 0, 160: 1.0, 161: 2.0, 34: 3.0, 'lane': 0}
# service: {'a_end': 253, 'z_end': 20, 'weight': 10}
# path: {253: 0, 134: 1.0, 223: 3.0, 20: 4.0, 'lane': 0}
# service: {'a_end': 118, 'z_end': 1, 'weight': 1}
# path: {118: 0, 137: 1.0, 38: 2.0, 1: 4.0, 'lane': 0}
# service: {'a_end': 133, 'z_end': 238, 'weight': 10}
# path: {133: 0, 108: 1.0, 87: 3.0, 238: 4.0, 'lane': 0}
# service: {'a_end': 62, 'z_end': 6, 'weight': 10}
# path: {62: 0, 6: 1.0, 'lane': 0}
# service: {'a_end': 18, 'z_end': 40, 'weight': 1}
# path: {18: 0, 3: 1.0, 138: 3.0, 40: 4.0, 'lane': 0}
# service: {'a_end': 232, 'z_end': 215, 'weight': 1}
# path: {232: 0, 124: 1.0, 215: 3.0, 'lane': 0}
# service: {'a_end': 208, 'z_end': 153, 'weight': 1}
# path: {208: 0, 225: 1.0, 128: 2.0, 200: 3.0, 153: 4.0, 'lane': 0}
# service: {'a_end': 135, 'z_end': 234, 'weight': 1}
# path: {135: 0, 10: 1.0, 20: 2.0, 115: 3.0, 234: 4.0, 'lane': 0}
# service: {'a_end': 102, 'z_end': 248, 'weight': 1}
# path: {102: 0, 156: 1.0, 173: 3.0, 248: 4.0, 'lane': 0}
# service: {'a_end': 212, 'z_end': 167, 'weight': 4}
# path: {212: 0, 137: 1.0, 38: 2.0, 42: 3.0, 167: 4.0, 'lane': 0}
# service: {'a_end': 89, 'z_end': 137, 'weight': 10}
# path: {89: 0, 186: 1.0, 94: 2.0, 49: 3.0, 137: 4.0, 'lane': 0}
# service: {'a_end': 225, 'z_end': 17, 'weight': 1}
# path: {225: 0, 138: 1.0, 40: 2.0, 17: 4.0, 'lane': 0}
# service: {'a_end': 102, 'z_end': 6, 'weight': 1}
# path: {102: 0, 149: 1.0, 6: 2.0, 'lane': 0}
# service: {'a_end': 63, 'z_end': 206, 'weight': 1}
# path: {63: 0, 75: 1.0, 196: 3.0, 206: 4.0, 'lane': 0}
# service: {'a_end': 144, 'z_end': 172, 'weight': 1}
# path: {144: 0, 189: 1.0, 55: 2.0, 172: 3.0, 'lane': 0}
# service: {'a_end': 71, 'z_end': 195, 'weight': 1}
# path: {71: 0, 164: 2.0, 195: 3.0, 'lane': 0}
# service: {'a_end': 109, 'z_end': 144, 'weight': 1}
# path: {109: 0, 234: 1.0, 144: 2.0, 'lane': 0}
# service: {'a_end': 24, 'z_end': 172, 'weight': 1}
# path: {24: 0, 181: 1.0, 52: 3.0, 172: 4.0, 'lane': 0}
# service: {'a_end': 71, 'z_end': 163, 'weight': 1}
# path: {71: 0, 206: 1.0, 196: 2.0, 75: 4.0, 163: 5.0, 'lane': 0}
# service: {'a_end': 143, 'z_end': 229, 'weight': 1}
# path: {143: 0, 229: 2.0, 'lane': 0}
# service: {'a_end': 248, 'z_end': 28, 'weight': 1}
# path: {248: 0, 18: 1.0, 28: 2.0, 'lane': 0}
# service: {'a_end': 157, 'z_end': 126, 'weight': 4}
# path: {157: 0, 19: 1.0, 69: 2.0, 204: 3.0, 126: 4.0, 'lane': 0}
# service: {'a_end': 239, 'z_end': 79, 'weight': 1}
# path: {239: 0, 81: 1.0, 79: 2.0, 'lane': 0}
# service: {'a_end': 33, 'z_end': 212, 'weight': 1}
# path: {33: 0, 84: 1.0, 38: 3.0, 137: 4.0, 212: 5.0, 'lane': 0}
# service: {'a_end': 79, 'z_end': 224, 'weight': 1}
# path: {79: 0, 183: 1.0, 39: 3.0, 224: 4.0, 'lane': 0}
# service: {'a_end': 79, 'z_end': 64, 'weight': 1}
# path: {79: 0, 81: 1.0, 34: 2.0, 161: 3.0, 64: 5.0, 'lane': 0}
# service: {'a_end': 129, 'z_end': 20, 'weight': 4}
# path: {129: 0, 15: 1.0, 221: 2.0, 20: 4.0, 'lane': 0}
# service: {'a_end': 35, 'z_end': 62, 'weight': 1}
# path: {35: 0, 195: 1.0, 222: 2.0, 62: 4.0, 'lane': 0}
# service: {'a_end': 179, 'z_end': 80, 'weight': 1}
# path: {179: 0, 229: 2.0, 176: 3.0, 80: 4.0, 'lane': 0}
# service: {'a_end': 30, 'z_end': 197, 'weight': 1}
# path: {30: 0, 204: 1.0, 69: 2.0, 197: 3.0, 'lane': 0}
# service: {'a_end': 7, 'z_end': 104, 'weight': 1}
# path: {7: 0, 34: 2.0, 104: 4.0, 'lane': 0}
# service: {'a_end': 234, 'z_end': 191, 'weight': 1}
# path: {234: 0, 227: 1.0, 136: 2.0, 191: 3.0, 'lane': 0}
# service: {'a_end': 129, 'z_end': 77, 'weight': 1}
# path: {129: 0, 15: 1.0, 187: 2.0, 77: 4.0, 'lane': 0}
# service: {'a_end': 45, 'z_end': 134, 'weight': 1}
# path: {45: 0, 11: 1.0, 22: 2.0, 134: 3.0, 'lane': 0}
# service: {'a_end': 164, 'z_end': 47, 'weight': 1}
# path: {164: 0, 29: 2.0, 47: 5.0, 'lane': 0}
# service: {'a_end': 120, 'z_end': 165, 'weight': 1}
# path: {120: 0, 80: 1.0, 238: 2.0, 163: 3.0, 165: 4.0, 'lane': 0}
# service: {'a_end': 84, 'z_end': 131, 'weight': 1}
# path: {84: 0, 90: 1.0, 240: 2.0, 28: 3.0, 131: 5.0, 'lane': 0}
# service: {'a_end': 115, 'z_end': 220, 'weight': 1}
# path: {115: 0, 234: 1.0, 227: 2.0, 107: 3.0, 220: 4.0, 'lane': 0}
# service: {'a_end': 168, 'z_end': 242, 'weight': 1}
# path: {168: 0, 239: 1.0, 30: 2.0, 242: 3.0, 'lane': 0}
# service: {'a_end': 85, 'z_end': 133, 'weight': 4}
# path: {85: 0, 178: 2.0, 108: 3.0, 133: 4.0, 'lane': 1}
# service: {'a_end': 86, 'z_end': 17, 'weight': 4}
# path: {86: 0, 243: 2.0, 17: 3.0, 'lane': 0}
# service: {'a_end': 5, 'z_end': 239, 'weight': 1}
# path: {5: 0, 44: 2.0, 177: 4.0, 239: 5.0, 'lane': 0}
# service: {'a_end': 167, 'z_end': 241, 'weight': 1}
# path: {167: 0, 42: 1.0, 155: 2.0, 241: 3.0, 'lane': 0}
# service: {'a_end': 26, 'z_end': 121, 'weight': 4}
# path: {26: 0, 30: 1.0, 242: 2.0, 180: 3.0, 121: 4.0, 'lane': 0}
# service: {'a_end': 224, 'z_end': 124, 'weight': 4}
# path: {224: 0, 39: 1.0, 183: 3.0, 188: 4.0, 124: 5.0, 'lane': 0}
# service: {'a_end': 66, 'z_end': 238, 'weight': 1}
# path: {66: 0, 58: 1.0, 244: 2.0, 238: 4.0, 'lane': 0}
# service: {'a_end': 122, 'z_end': 64, 'weight': 1}
# path: {122: 0, 102: 1.0, 253: 3.0, 64: 4.0, 'lane': 0}
# service: {'a_end': 148, 'z_end': 65, 'weight': 4}
# path: {148: 0, 77: 1.0, 127: 2.0, 65: 4.0, 'lane': 0}
# service: {'a_end': 228, 'z_end': 177, 'weight': 1}
# path: {228: 0, 36: 2.0, 239: 3.0, 177: 4.0, 'lane': 0}
# service: {'a_end': 224, 'z_end': 172, 'weight': 1}
# path: {224: 0, 39: 1.0, 172: 2.0, 'lane': 0}
# service: {'a_end': 43, 'z_end': 175, 'weight': 1}
# path: {43: 0, 198: 1.0, 209: 2.0, 66: 4.0, 175: 5.0, 'lane': 0}
# service: {'a_end': 47, 'z_end': 211, 'weight': 1}
# path: {47: 0, 28: 1.0, 172: 2.0, 55: 3.0, 211: 4.0, 'lane': 0}
# service: {'a_end': 47, 'z_end': 131, 'weight': 1}
# path: {47: 0, 28: 1.0, 131: 3.0, 'lane': 0}
# service: {'a_end': 72, 'z_end': 107, 'weight': 1}
# path: {72: 0, 162: 2.0, 107: 3.0, 'lane': 0}
# service: {'a_end': 170, 'z_end': 57, 'weight': 1}
# path: {170: 0, 194: 1.0, 57: 2.0, 'lane': 0}
# service: {'a_end': 239, 'z_end': 54, 'weight': 1}
# path: {239: 0, 83: 1.0, 123: 2.0, 24: 3.0, 54: 4.0, 'lane': 0}
# service: {'a_end': 122, 'z_end': 94, 'weight': 1}
# path: {122: 0, 102: 1.0, 198: 2.0, 110: 3.0, 94: 4.0, 'lane': 0}
# service: {'a_end': 239, 'z_end': 110, 'weight': 1}
# path: {239: 0, 36: 1.0, 110: 3.0, 'lane': 0}
# service: {'a_end': 230, 'z_end': 189, 'weight': 1}
# path: {230: 0, 42: 1.0, 155: 2.0, 189: 3.0, 'lane': 0}
# service: {'a_end': 208, 'z_end': 158, 'weight': 1}
# path: {208: 0, 80: 2.0, 158: 3.0, 'lane': 0}
# service: {'a_end': 76, 'z_end': 130, 'weight': 1}
# path: {76: 0, 126: 1.0, 130: 3.0, 'lane': 0}
# service: {'a_end': 245, 'z_end': 97, 'weight': 1}
# path: {245: 0, 231: 2.0, 235: 3.0, 118: 5.0, 97: 6.0, 'lane': 0}
# service: {'a_end': 169, 'z_end': 160, 'weight': 1}
# path: {169: 0, 236: 2.0, 41: 3.0, 160: 4.0, 'lane': 0}
# service: {'a_end': 235, 'z_end': 97, 'weight': 1}
# path: {235: 0, 118: 2.0, 97: 3.0, 'lane': 0}
# service: {'a_end': 77, 'z_end': 204, 'weight': 1}
# path: {77: 0, 148: 1.0, 30: 2.0, 204: 3.0, 'lane': 0}
# service: {'a_end': 207, 'z_end': 164, 'weight': 1}
# path: {207: 0, 115: 1.0, 195: 3.0, 164: 4.0, 'lane': 0}
# service: {'a_end': 212, 'z_end': 177, 'weight': 1}
# path: {212: 0, 137: 1.0, 118: 2.0, 185: 3.0, 177: 4.0, 'lane': 0}
# service: {'a_end': 120, 'z_end': 95, 'weight': 1}
# path: {120: 0, 21: 1.0, 156: 2.0, 184: 3.0, 95: 4.0, 'lane': 0}
# service: {'a_end': 79, 'z_end': 132, 'weight': 1}
# path: {79: 0, 50: 1.0, 132: 3.0, 'lane': 0}
# service: {'a_end': 35, 'z_end': 184, 'weight': 1}
# path: {35: 0, 90: 1.0, 166: 2.0, 184: 3.0, 'lane': 0}
# service: {'a_end': 40, 'z_end': 244, 'weight': 1}
# path: {40: 0, 145: 1.0, 244: 3.0, 'lane': 0}
# service: {'a_end': 75, 'z_end': 135, 'weight': 1}
# path: {75: 0, 117: 1.0, 175: 2.0, 135: 3.0, 'lane': 0}
# service: {'a_end': 239, 'z_end': 82, 'weight': 10}
# path: {239: 0, 177: 1.0, 104: 2.0, 120: 3.0, 82: 4.0, 'lane': 1}
# service: {'a_end': 5, 'z_end': 176, 'weight': 1}
# path: {5: 0, 4: 1.0, 246: 2.0, 80: 3.0, 176: 4.0, 'lane': 0}
# service: {'a_end': 48, 'z_end': 30, 'weight': 1}
# path: {48: 0, 142: 2.0, 103: 3.0, 30: 4.0, 'lane': 0}
# service: {'a_end': 197, 'z_end': 85, 'weight': 1}
# path: {197: 0, 229: 1.0, 100: 2.0, 85: 4.0, 'lane': 0}
# service: {'a_end': 143, 'z_end': 8, 'weight': 1}
# path: {143: 0, 229: 2.0, 8: 3.0, 'lane': 0}
# service: {'a_end': 148, 'z_end': 141, 'weight': 1}
# path: {148: 0, 77: 1.0, 31: 2.0, 141: 3.0, 'lane': 0}
# service: {'a_end': 235, 'z_end': 64, 'weight': 1}
# path: {235: 0, 161: 1.0, 64: 3.0, 'lane': 0}
# service: {'a_end': 216, 'z_end': 100, 'weight': 1}
# path: {216: 0, 42: 1.0, 90: 2.0, 240: 3.0, 100: 4.0, 'lane': 0}
# service: {'a_end': 185, 'z_end': 201, 'weight': 1}
# path: {185: 0, 102: 1.0, 156: 2.0, 56: 3.0, 201: 4.0, 'lane': 0}
# service: {'a_end': 210, 'z_end': 162, 'weight': 1}
# path: {210: 0, 107: 1.0, 162: 2.0, 'lane': 0}
# service: {'a_end': 136, 'z_end': 9, 'weight': 1}
# path: {136: 0, 227: 1.0, 159: 2.0, 16: 3.0, 9: 4.0, 'lane': 0}
# service: {'a_end': 180, 'z_end': 113, 'weight': 1}
# path: {180: 0, 121: 1.0, 57: 2.0, 194: 3.0, 113: 4.0, 'lane': 0}
# service: {'a_end': 168, 'z_end': 1, 'weight': 1}
# path: {168: 0, 90: 1.0, 139: 2.0, 1: 3.0, 'lane': 0}
# service: {'a_end': 36, 'z_end': 210, 'weight': 1}
# path: {36: 0, 239: 1.0, 168: 2.0, 107: 4.0, 210: 5.0, 'lane': 0}
# service: {'a_end': 152, 'z_end': 127, 'weight': 1}
# path: {152: 0, 122: 1.0, 77: 2.0, 127: 3.0, 'lane': 0}
# service: {'a_end': 156, 'z_end': 217, 'weight': 1}
# path: {156: 0, 21: 1.0, 120: 2.0, 82: 3.0, 217: 4.0, 'lane': 0}
# service: {'a_end': 95, 'z_end': 67, 'weight': 1}
# path: {95: 0, 41: 1.0, 232: 2.0, 67: 5.0, 'lane': 0}
# service: {'a_end': 112, 'z_end': 210, 'weight': 4}
# path: {112: 0, 224: 1.0, 131: 2.0, 170: 3.0, 210: 4.0, 'lane': 0}
# service: {'a_end': 132, 'z_end': 35, 'weight': 1}
# path: {132: 0, 232: 1.0, 240: 2.0, 90: 3.0, 35: 4.0, 'lane': 0}
# service: {'a_end': 34, 'z_end': 222, 'weight': 1}
# path: {34: 0, 181: 1.0, 37: 2.0, 36: 3.0, 222: 5.0, 'lane': 0}
# service: {'a_end': 235, 'z_end': 99, 'weight': 1}
# path: {235: 0, 52: 1.0, 50: 2.0, 79: 3.0, 99: 4.0, 'lane': 0}
# service: {'a_end': 135, 'z_end': 18, 'weight': 4}
# path: {135: 0, 18: 2.0, 'lane': 0}
# service: {'a_end': 191, 'z_end': 234, 'weight': 1}
# path: {191: 0, 136: 1.0, 227: 2.0, 234: 3.0, 'lane': 0}
# service: {'a_end': 85, 'z_end': 214, 'weight': 1}
# path: {85: 0, 71: 1.0, 206: 2.0, 196: 3.0, 214: 5.0, 'lane': 0}
# service: {'a_end': 6, 'z_end': 49, 'weight': 4}
# path: {6: 0, 149: 1.0, 70: 2.0, 94: 3.0, 49: 4.0, 'lane': 1}
# service: {'a_end': 104, 'z_end': 147, 'weight': 1}
# path: {104: 0, 120: 1.0, 82: 2.0, 147: 3.0, 'lane': 0}
# service: {'a_end': 249, 'z_end': 121, 'weight': 1}
# path: {249: 0, 171: 1.0, 85: 2.0, 121: 4.0, 'lane': 0}
# service: {'a_end': 0, 'z_end': 36, 'weight': 1}
# path: {0: 0, 181: 1.0, 37: 2.0, 36: 3.0, 'lane': 0}
# service: {'a_end': 249, 'z_end': 108, 'weight': 1}
# path: {249: 0, 73: 1.0, 52: 3.0, 108: 4.0, 'lane': 0}
# service: {'a_end': 246, 'z_end': 249, 'weight': 1}
# path: {246: 0, 143: 1.0, 93: 3.0, 73: 4.0, 249: 5.0, 'lane': 0}
# service: {'a_end': 16, 'z_end': 97, 'weight': 1}
# path: {16: 0, 9: 1.0, 97: 3.0, 'lane': 0}
# service: {'a_end': 63, 'z_end': 194, 'weight': 10}
# path: {63: 0, 59: 2.0, 194: 4.0, 'lane': 0}
# service: {'a_end': 74, 'z_end': 194, 'weight': 1}
# path: {74: 0, 40: 1.0, 17: 3.0, 194: 4.0, 'lane': 0}
# service: {'a_end': 76, 'z_end': 196, 'weight': 1}
# path: {76: 0, 75: 2.0, 196: 4.0, 'lane': 0}
# service: {'a_end': 227, 'z_end': 156, 'weight': 1}
# path: {227: 0, 159: 1.0, 156: 2.0, 'lane': 0}
# service: {'a_end': 3, 'z_end': 230, 'weight': 1}
# path: {3: 0, 125: 1.0, 98: 2.0, 230: 3.0, 'lane': 0}
# service: {'a_end': 80, 'z_end': 87, 'weight': 1}
# path: {80: 0, 238: 1.0, 87: 2.0, 'lane': 1}
# service: {'a_end': 0, 'z_end': 122, 'weight': 4}
# path: {0: 0, 181: 1.0, 24: 2.0, 123: 3.0, 122: 4.0, 'lane': 0}
# service: {'a_end': 195, 'z_end': 114, 'weight': 1}
# path: {195: 0, 115: 2.0, 207: 3.0, 114: 4.0, 'lane': 0}
# service: {'a_end': 166, 'z_end': 25, 'weight': 1}
# path: {166: 0, 191: 1.0, 14: 2.0, 25: 4.0, 'lane': 0}
# service: {'a_end': 91, 'z_end': 125, 'weight': 1}
# path: {91: 0, 156: 1.0, 21: 2.0, 98: 3.0, 125: 4.0, 'lane': 0}
# service: {'a_end': 242, 'z_end': 195, 'weight': 1}
# path: {242: 0, 1: 3.0, 195: 4.0, 'lane': 0}
# service: {'a_end': 122, 'z_end': 146, 'weight': 1}
# path: {122: 0, 2: 2.0, 65: 3.0, 146: 4.0, 'lane': 0}
# service: {'a_end': 186, 'z_end': 45, 'weight': 1}
# path: {186: 0, 26: 1.0, 13: 2.0, 45: 3.0, 'lane': 0}
# service: {'a_end': 30, 'z_end': 62, 'weight': 1}
# path: {30: 0, 204: 1.0, 109: 2.0, 202: 3.0, 62: 5.0, 'lane': 0}
# service: {'a_end': 85, 'z_end': 123, 'weight': 1}
# path: {85: 0, 24: 2.0, 123: 3.0, 'lane': 0}
# service: {'a_end': 99, 'z_end': 27, 'weight': 1}
# path: {99: 0, 79: 1.0, 50: 2.0, 27: 4.0, 'lane': 0}
# service: {'a_end': 49, 'z_end': 51, 'weight': 1}
# path: {49: 0, 125: 1.0, 43: 2.0, 51: 4.0, 'lane': 0}
# service: {'a_end': 122, 'z_end': 189, 'weight': 1}
# path: {122: 0, 78: 2.0, 231: 3.0, 189: 4.0, 'lane': 0}
# service: {'a_end': 24, 'z_end': 27, 'weight': 1}
# path: {24: 0, 54: 1.0, 231: 2.0, 27: 4.0, 'lane': 0}
# service: {'a_end': 101, 'z_end': 29, 'weight': 1}
# path: {101: 0, 40: 1.0, 39: 3.0, 29: 5.0, 'lane': 0}
# service: {'a_end': 44, 'z_end': 40, 'weight': 1}
# path: {44: 0, 101: 1.0, 40: 2.0, 'lane': 0}
# service: {'a_end': 179, 'z_end': 132, 'weight': 1}
# path: {179: 0, 228: 1.0, 202: 2.0, 247: 3.0, 132: 4.0, 'lane': 0}
# service: {'a_end': 88, 'z_end': 5, 'weight': 1}
# path: {88: 0, 82: 2.0, 4: 3.0, 5: 4.0, 'lane': 0}
# service: {'a_end': 228, 'z_end': 175, 'weight': 1}
# path: {228: 0, 179: 1.0, 66: 3.0, 175: 4.0, 'lane': 0}
# service: {'a_end': 172, 'z_end': 144, 'weight': 1}
# path: {172: 0, 55: 1.0, 189: 2.0, 144: 3.0, 'lane': 0}
# service: {'a_end': 42, 'z_end': 194, 'weight': 1}
# path: {42: 0, 90: 1.0, 166: 2.0, 194: 3.0, 'lane': 0}
# service: {'a_end': 218, 'z_end': 198, 'weight': 1}
# path: {218: 0, 102: 2.0, 198: 3.0, 'lane': 0}
# service: {'a_end': 223, 'z_end': 185, 'weight': 1}
# path: {223: 0, 79: 1.0, 99: 2.0, 123: 3.0, 185: 5.0, 'lane': 0}
# service: {'a_end': 95, 'z_end': 132, 'weight': 1}
# path: {95: 0, 41: 1.0, 232: 2.0, 132: 3.0, 'lane': 0}
# service: {'a_end': 136, 'z_end': 77, 'weight': 1}
# path: {136: 0, 122: 3.0, 77: 4.0, 'lane': 0}
# service: {'a_end': 48, 'z_end': 153, 'weight': 1}
# path: {48: 0, 29: 1.0, 54: 2.0, 153: 4.0, 'lane': 0}
# service: {'a_end': 89, 'z_end': 38, 'weight': 1}
# path: {89: 0, 126: 1.0, 174: 2.0, 199: 3.0, 38: 4.0, 'lane': 0}
# service: {'a_end': 147, 'z_end': 58, 'weight': 1}
# path: {147: 0, 82: 1.0, 149: 2.0, 58: 5.0, 'lane': 0}
# service: {'a_end': 49, 'z_end': 179, 'weight': 1}
# path: {49: 0, 155: 1.0, 53: 2.0, 179: 4.0, 'lane': 0}
# service: {'a_end': 159, 'z_end': 153, 'weight': 1}
# path: {159: 0, 22: 1.0, 134: 2.0, 153: 4.0, 'lane': 0}
# service: {'a_end': 214, 'z_end': 35, 'weight': 1}
# path: {214: 0, 154: 1.0, 215: 2.0, 35: 4.0, 'lane': 0}
# service: {'a_end': 36, 'z_end': 113, 'weight': 1}
# path: {36: 0, 37: 1.0, 209: 2.0, 113: 4.0, 'lane': 0}
# service: {'a_end': 31, 'z_end': 153, 'weight': 1}
# path: {31: 0, 169: 1.0, 89: 2.0, 153: 4.0, 'lane': 0}
# service: {'a_end': 236, 'z_end': 56, 'weight': 1}
# path: {236: 0, 105: 1.0, 220: 2.0, 107: 3.0, 56: 4.0, 'lane': 0}
# service: {'a_end': 82, 'z_end': 166, 'weight': 1}
# path: {82: 0, 120: 1.0, 129: 3.0, 166: 5.0, 'lane': 0}
# service: {'a_end': 128, 'z_end': 36, 'weight': 1}
# path: {128: 0, 239: 2.0, 36: 3.0, 'lane': 0}
# service: {'a_end': 48, 'z_end': 42, 'weight': 1}
# path: {48: 0, 29: 1.0, 216: 3.0, 42: 4.0, 'lane': 0}
# service: {'a_end': 77, 'z_end': 106, 'weight': 1}
# path: {77: 0, 127: 1.0, 106: 3.0, 'lane': 0}
# service: {'a_end': 51, 'z_end': 73, 'weight': 1}
# path: {51: 0, 224: 1.0, 39: 2.0, 172: 3.0, 73: 5.0, 'lane': 0}
# service: {'a_end': 6, 'z_end': 184, 'weight': 1}
# path: {6: 0, 64: 1.0, 253: 2.0, 184: 4.0, 'lane': 0}
# service: {'a_end': 207, 'z_end': 106, 'weight': 1}
# path: {207: 0, 115: 1.0, 111: 2.0, 98: 3.0, 106: 4.0, 'lane': 0}
# service: {'a_end': 189, 'z_end': 74, 'weight': 1}
# path: {189: 0, 225: 2.0, 127: 3.0, 74: 4.0, 'lane': 0}
# service: {'a_end': 1, 'z_end': 209, 'weight': 1}
# path: {1: 0, 38: 2.0, 199: 3.0, 209: 4.0, 'lane': 0}
# service: {'a_end': 102, 'z_end': 213, 'weight': 1}
# path: {102: 0, 198: 1.0, 110: 2.0, 213: 3.0, 'lane': 0}
# service: {'a_end': 70, 'z_end': 197, 'weight': 1}
# path: {70: 0, 149: 1.0, 250: 2.0, 130: 3.0, 197: 5.0, 'lane': 0}
# service: {'a_end': 180, 'z_end': 30, 'weight': 1}
# path: {180: 0, 242: 1.0, 30: 2.0, 'lane': 0}
# service: {'a_end': 122, 'z_end': 69, 'weight': 1}
# path: {122: 0, 136: 3.0, 69: 4.0, 'lane': 0}
# service: {'a_end': 247, 'z_end': 25, 'weight': 1}
# path: {247: 0, 132: 1.0, 25: 2.0, 'lane': 0}
# service: {'a_end': 107, 'z_end': 190, 'weight': 1}
# path: {107: 0, 210: 1.0, 19: 2.0, 190: 3.0, 'lane': 0}
# service: {'a_end': 199, 'z_end': 118, 'weight': 1}
# path: {199: 0, 38: 1.0, 137: 2.0, 118: 3.0, 'lane': 0}
# service: {'a_end': 142, 'z_end': 23, 'weight': 1}
# path: {142: 0, 94: 1.0, 120: 2.0, 164: 3.0, 23: 4.0, 'lane': 0}
# service: {'a_end': 120, 'z_end': 239, 'weight': 1}
# path: {120: 0, 104: 1.0, 177: 2.0, 239: 3.0, 'lane': 0}
# service: {'a_end': 229, 'z_end': 19, 'weight': 1}
# path: {229: 0, 197: 1.0, 69: 2.0, 19: 3.0, 'lane': 0}
# service: {'a_end': 61, 'z_end': 11, 'weight': 4}
# path: {61: 0, 49: 1.0, 94: 2.0, 70: 3.0, 11: 4.0, 'lane': 1}
# service: {'a_end': 143, 'z_end': 230, 'weight': 1}
# path: {143: 0, 229: 2.0, 8: 3.0, 230: 4.0, 'lane': 0}
# service: {'a_end': 160, 'z_end': 115, 'weight': 1}
# path: {160: 0, 164: 1.0, 195: 2.0, 115: 4.0, 'lane': 0}
# service: {'a_end': 159, 'z_end': 218, 'weight': 4}
# path: {159: 0, 156: 1.0, 102: 2.0, 218: 4.0, 'lane': 0}
# service: {'a_end': 53, 'z_end': 150, 'weight': 1}
# path: {53: 0, 155: 1.0, 42: 2.0, 61: 3.0, 150: 4.0, 'lane': 0}
# service: {'a_end': 0, 'z_end': 34, 'weight': 4}
# path: {0: 0, 181: 1.0, 34: 2.0, 'lane': 0}
# service: {'a_end': 29, 'z_end': 123, 'weight': 1}
# path: {29: 0, 54: 1.0, 24: 2.0, 123: 3.0, 'lane': 0}
# service: {'a_end': 159, 'z_end': 194, 'weight': 1}
# path: {159: 0, 22: 1.0, 184: 2.0, 166: 3.0, 194: 4.0, 'lane': 0}
# service: {'a_end': 65, 'z_end': 4, 'weight': 1}
# path: {65: 0, 140: 1.0, 25: 2.0, 4: 3.0, 'lane': 0}
# service: {'a_end': 141, 'z_end': 198, 'weight': 1}
# path: {141: 0, 240: 2.0, 43: 3.0, 198: 4.0, 'lane': 0}
# service: {'a_end': 18, 'z_end': 89, 'weight': 1}
# path: {18: 0, 76: 1.0, 128: 2.0, 89: 3.0, 'lane': 0}
# service: {'a_end': 46, 'z_end': 131, 'weight': 1}
# path: {46: 0, 246: 1.0, 220: 2.0, 105: 3.0, 131: 5.0, 'lane': 0}
# service: {'a_end': 112, 'z_end': 82, 'weight': 1}
# path: {112: 0, 203: 1.0, 4: 3.0, 82: 4.0, 'lane': 0}
# service: {'a_end': 184, 'z_end': 201, 'weight': 1}
# path: {184: 0, 156: 1.0, 56: 2.0, 201: 3.0, 'lane': 0}
# service: {'a_end': 197, 'z_end': 123, 'weight': 1}
# path: {197: 0, 157: 1.0, 147: 2.0, 99: 3.0, 123: 4.0, 'lane': 0}
# service: {'a_end': 160, 'z_end': 115, 'weight': 1}
# path: {160: 0, 164: 1.0, 195: 2.0, 115: 4.0, 'lane': 0}
# service: {'a_end': 104, 'z_end': 16, 'weight': 1}
# path: {104: 0, 46: 2.0, 237: 3.0, 16: 4.0, 'lane': 0}
# service: {'a_end': 48, 'z_end': 186, 'weight': 1}
# path: {48: 0, 142: 2.0, 74: 3.0, 186: 4.0, 'lane': 0}
# service: {'a_end': 17, 'z_end': 44, 'weight': 1}
# path: {17: 0, 40: 2.0, 101: 3.0, 44: 4.0, 'lane': 0}
# service: {'a_end': 6, 'z_end': 154, 'weight': 1}
# path: {6: 0, 149: 1.0, 82: 2.0, 215: 4.0, 154: 5.0, 'lane': 0}
# service: {'a_end': 159, 'z_end': 1, 'weight': 1}
# path: {159: 0, 16: 1.0, 9: 2.0, 1: 5.0, 'lane': 0}
# service: {'a_end': 18, 'z_end': 27, 'weight': 1}
# path: {18: 0, 141: 2.0, 11: 3.0, 27: 4.0, 'lane': 0}
# service: {'a_end': 80, 'z_end': 160, 'weight': 1}
# path: {80: 0, 120: 1.0, 164: 2.0, 160: 3.0, 'lane': 0}
# service: {'a_end': 44, 'z_end': 72, 'weight': 1}
# path: {44: 0, 141: 1.0, 11: 2.0, 45: 3.0, 72: 4.0, 'lane': 0}
# service: {'a_end': 7, 'z_end': 152, 'weight': 1}
# path: {7: 0, 204: 1.0, 126: 2.0, 13: 3.0, 152: 5.0, 'lane': 0}
# service: {'a_end': 114, 'z_end': 177, 'weight': 1}
# path: {114: 0, 50: 1.0, 104: 2.0, 177: 3.0, 'lane': 0}
# service: {'a_end': 245, 'z_end': 90, 'weight': 1}
# path: {245: 0, 230: 3.0, 42: 4.0, 90: 5.0, 'lane': 0}
# service: {'a_end': 178, 'z_end': 136, 'weight': 1}
# path: {178: 0, 108: 1.0, 206: 2.0, 110: 3.0, 136: 5.0, 'lane': 0}
# service: {'a_end': 240, 'z_end': 99, 'weight': 1}
# path: {240: 0, 90: 1.0, 168: 2.0, 99: 4.0, 'lane': 0}
# service: {'a_end': 48, 'z_end': 11, 'weight': 1}
# path: {48: 0, 51: 1.0, 31: 3.0, 141: 4.0, 11: 5.0, 'lane': 0}
# service: {'a_end': 139, 'z_end': 216, 'weight': 1}
# path: {139: 0, 90: 1.0, 42: 2.0, 216: 3.0, 'lane': 0}
# service: {'a_end': 135, 'z_end': 2, 'weight': 1}
# path: {135: 0, 175: 1.0, 2: 3.0, 'lane': 0}
# service: {'a_end': 222, 'z_end': 206, 'weight': 1}
# path: {222: 0, 62: 2.0, 108: 3.0, 206: 4.0, 'lane': 0}
# service: {'a_end': 163, 'z_end': 226, 'weight': 1}
# path: {163: 0, 74: 1.0, 86: 2.0, 226: 3.0, 'lane': 0}
# service: {'a_end': 161, 'z_end': 251, 'weight': 4}
# path: {161: 0, 252: 1.0, 188: 2.0, 251: 4.0, 'lane': 0}
# service: {'a_end': 28, 'z_end': 238, 'weight': 1}
# path: {28: 0, 238: 2.0, 'lane': 0}
# service: {'a_end': 158, 'z_end': 205, 'weight': 1}
# path: {158: 0, 40: 1.0, 154: 2.0, 205: 3.0, 'lane': 0}
# service: {'a_end': 110, 'z_end': 75, 'weight': 1}
# path: {110: 0, 206: 1.0, 196: 2.0, 75: 4.0, 'lane': 0}
# service: {'a_end': 70, 'z_end': 227, 'weight': 1}
# path: {70: 0, 55: 1.0, 211: 2.0, 227: 3.0, 'lane': 0}
# service: {'a_end': 28, 'z_end': 100, 'weight': 1}
# path: {28: 0, 240: 1.0, 100: 2.0, 'lane': 0}
# service: {'a_end': 45, 'z_end': 68, 'weight': 1}
# path: {45: 0, 207: 1.0, 115: 2.0, 68: 4.0, 'lane': 0}
# service: {'a_end': 17, 'z_end': 29, 'weight': 1}
# path: {17: 0, 54: 2.0, 29: 3.0, 'lane': 0}
# service: {'a_end': 169, 'z_end': 99, 'weight': 1}
# path: {169: 0, 89: 1.0, 186: 2.0, 99: 4.0, 'lane': 1}
# service: {'a_end': 108, 'z_end': 171, 'weight': 1}
# path: {108: 0, 178: 1.0, 85: 3.0, 171: 4.0, 'lane': 0}
# service: {'a_end': 32, 'z_end': 133, 'weight': 1}
# path: {32: 0, 127: 2.0, 77: 3.0, 16: 4.0, 133: 5.0, 'lane': 0}
# service: {'a_end': 145, 'z_end': 93, 'weight': 1}
# path: {145: 0, 140: 1.0, 25: 2.0, 93: 4.0, 'lane': 0}
# service: {'a_end': 224, 'z_end': 91, 'weight': 1}
# path: {224: 0, 203: 2.0, 91: 4.0, 'lane': 0}
# service: {'a_end': 237, 'z_end': 105, 'weight': 1}
# path: {237: 0, 220: 2.0, 105: 3.0, 'lane': 0}
# service: {'a_end': 19, 'z_end': 11, 'weight': 4}
# path: {19: 0, 69: 1.0, 116: 2.0, 11: 4.0, 'lane': 0}
# service: {'a_end': 158, 'z_end': 215, 'weight': 4}
# path: {158: 0, 40: 1.0, 154: 2.0, 215: 3.0, 'lane': 0}
# service: {'a_end': 157, 'z_end': 46, 'weight': 1}
# path: {157: 0, 197: 1.0, 246: 3.0, 46: 4.0, 'lane': 0}
# service: {'a_end': 122, 'z_end': 1, 'weight': 1}
# path: {122: 0, 123: 1.0, 24: 2.0, 1: 3.0, 'lane': 0}
# service: {'a_end': 95, 'z_end': 40, 'weight': 1}
# path: {95: 0, 209: 1.0, 154: 2.0, 40: 3.0, 'lane': 0}
# service: {'a_end': 119, 'z_end': 167, 'weight': 1}
# path: {119: 0, 130: 1.0, 152: 2.0, 122: 3.0, 167: 4.0, 'lane': 0}
# service: {'a_end': 87, 'z_end': 196, 'weight': 1}
# path: {87: 0, 75: 1.0, 196: 3.0, 'lane': 0}
# service: {'a_end': 100, 'z_end': 168, 'weight': 1}
# path: {100: 0, 240: 1.0, 90: 2.0, 168: 3.0, 'lane': 0}
# service: {'a_end': 46, 'z_end': 132, 'weight': 1}
# path: {46: 0, 60: 1.0, 25: 3.0, 132: 4.0, 'lane': 0}
# service: {'a_end': 177, 'z_end': 184, 'weight': 1}
# path: {177: 0, 103: 1.0, 159: 2.0, 22: 3.0, 184: 4.0, 'lane': 0}
# service: {'a_end': 218, 'z_end': 45, 'weight': 1}
# path: {218: 0, 102: 2.0, 149: 3.0, 45: 5.0, 'lane': 0}
# service: {'a_end': 248, 'z_end': 131, 'weight': 1}
# path: {248: 0, 18: 1.0, 28: 2.0, 131: 4.0, 'lane': 0}
# service: {'a_end': 95, 'z_end': 167, 'weight': 4}
# path: {95: 0, 84: 1.0, 90: 2.0, 42: 3.0, 167: 4.0, 'lane': 0}
# service: {'a_end': 59, 'z_end': 85, 'weight': 10}
# path: {59: 0, 60: 1.0, 190: 2.0, 85: 4.0, 'lane': 0}
# service: {'a_end': 64, 'z_end': 4, 'weight': 1}
# path: {64: 0, 6: 1.0, 62: 2.0, 5: 3.0, 4: 4.0, 'lane': 1}
# service: {'a_end': 5, 'z_end': 166, 'weight': 1}
# path: {5: 0, 172: 1.0, 140: 2.0, 145: 3.0, 166: 5.0, 'lane': 0}
# service: {'a_end': 171, 'z_end': 23, 'weight': 1}
# path: {171: 0, 249: 1.0, 14: 3.0, 23: 4.0, 'lane': 0}
# service: {'a_end': 36, 'z_end': 5, 'weight': 1}
# path: {36: 0, 222: 2.0, 4: 3.0, 5: 4.0, 'lane': 0}
# service: {'a_end': 128, 'z_end': 80, 'weight': 1}
# path: {128: 0, 225: 1.0, 208: 2.0, 80: 4.0, 'lane': 0}
# service: {'a_end': 221, 'z_end': 158, 'weight': 1}
# path: {221: 0, 113: 1.0, 80: 2.0, 158: 3.0, 'lane': 0}
# service: {'a_end': 179, 'z_end': 125, 'weight': 1}
# path: {179: 0, 229: 2.0, 98: 4.0, 125: 5.0, 'lane': 0}
# service: {'a_end': 161, 'z_end': 63, 'weight': 4}
# path: {161: 0, 34: 1.0, 81: 2.0, 79: 3.0, 63: 4.0, 'lane': 0}
# service: {'a_end': 196, 'z_end': 242, 'weight': 1}
# path: {196: 0, 214: 2.0, 20: 3.0, 242: 5.0, 'lane': 0}
# service: {'a_end': 156, 'z_end': 33, 'weight': 1}
# path: {156: 0, 56: 1.0, 201: 2.0, 33: 4.0, 'lane': 0}
# service: {'a_end': 211, 'z_end': 38, 'weight': 1}
# path: {211: 0, 227: 1.0, 137: 3.0, 38: 4.0, 'lane': 0}
# service: {'a_end': 156, 'z_end': 38, 'weight': 1}
# path: {156: 0, 145: 1.0, 40: 2.0, 101: 3.0, 38: 4.0, 'lane': 0}
# service: {'a_end': 57, 'z_end': 221, 'weight': 1}
# path: {57: 0, 194: 1.0, 113: 2.0, 221: 3.0, 'lane': 0}
# service: {'a_end': 18, 'z_end': 163, 'weight': 1}
# path: {18: 0, 76: 1.0, 75: 3.0, 163: 4.0, 'lane': 0}
# service: {'a_end': 240, 'z_end': 179, 'weight': 1}
# path: {240: 0, 28: 1.0, 228: 2.0, 179: 3.0, 'lane': 0}
# service: {'a_end': 28, 'z_end': 83, 'weight': 1}
# path: {28: 0, 240: 1.0, 43: 2.0, 83: 3.0, 'lane': 0}
# service: {'a_end': 136, 'z_end': 9, 'weight': 4}
# path: {136: 0, 227: 1.0, 159: 2.0, 16: 3.0, 9: 4.0, 'lane': 0}
# service: {'a_end': 224, 'z_end': 195, 'weight': 1}
# path: {224: 0, 51: 1.0, 1: 4.0, 195: 5.0, 'lane': 0}
# service: {'a_end': 214, 'z_end': 237, 'weight': 1}
# path: {214: 0, 7: 1.0, 14: 2.0, 191: 3.0, 237: 4.0, 'lane': 0}
# service: {'a_end': 193, 'z_end': 57, 'weight': 4}
# path: {193: 0, 157: 1.0, 170: 2.0, 194: 3.0, 57: 4.0, 'lane': 0}
# service: {'a_end': 12, 'z_end': 134, 'weight': 1}
# path: {12: 0, 91: 1.0, 134: 2.0, 'lane': 0}
# service: {'a_end': 8, 'z_end': 84, 'weight': 1}
# path: {8: 0, 229: 1.0, 100: 2.0, 33: 3.0, 84: 4.0, 'lane': 0}
# service: {'a_end': 133, 'z_end': 107, 'weight': 1}
# path: {133: 0, 162: 3.0, 107: 4.0, 'lane': 0}
# service: {'a_end': 25, 'z_end': 129, 'weight': 1}
# path: {25: 0, 13: 1.0, 92: 2.0, 129: 4.0, 'lane': 0}
# service: {'a_end': 57, 'z_end': 253, 'weight': 1}
# path: {57: 0, 143: 1.0, 134: 2.0, 253: 3.0, 'lane': 1}
# service: {'a_end': 65, 'z_end': 42, 'weight': 1}
# path: {65: 0, 127: 2.0, 225: 3.0, 42: 4.0, 'lane': 0}
# service: {'a_end': 204, 'z_end': 197, 'weight': 1}
# path: {204: 0, 69: 1.0, 197: 2.0, 'lane': 0}
# service: {'a_end': 208, 'z_end': 71, 'weight': 1}
# path: {208: 0, 190: 1.0, 85: 3.0, 71: 4.0, 'lane': 1}
# service: {'a_end': 204, 'z_end': 27, 'weight': 1}
# path: {204: 0, 109: 1.0, 45: 2.0, 11: 3.0, 27: 4.0, 'lane': 0}
# service: {'a_end': 225, 'z_end': 219, 'weight': 1}
# path: {225: 0, 169: 1.0, 219: 2.0, 'lane': 0}
# service: {'a_end': 224, 'z_end': 84, 'weight': 1}
# path: {224: 0, 112: 1.0, 161: 2.0, 95: 3.0, 84: 4.0, 'lane': 0}
# service: {'a_end': 46, 'z_end': 4, 'weight': 4}
# path: {46: 0, 246: 1.0, 4: 2.0, 'lane': 0}
# service: {'a_end': 53, 'z_end': 88, 'weight': 4}
# path: {53: 0, 205: 2.0, 88: 4.0, 'lane': 0}
# service: {'a_end': 126, 'z_end': 180, 'weight': 1}
# path: {126: 0, 204: 1.0, 30: 2.0, 242: 3.0, 180: 4.0, 'lane': 0}
# service: {'a_end': 47, 'z_end': 201, 'weight': 10}
# path: {47: 0, 28: 1.0, 12: 2.0, 201: 4.0, 'lane': 1}
# service: {'a_end': 12, 'z_end': 58, 'weight': 1}
# path: {12: 0, 146: 1.0, 244: 2.0, 58: 3.0, 'lane': 0}
# service: {'a_end': 57, 'z_end': 234, 'weight': 1}
# path: {57: 0, 111: 1.0, 115: 2.0, 234: 3.0, 'lane': 0}
# service: {'a_end': 156, 'z_end': 158, 'weight': 1}
# path: {156: 0, 145: 1.0, 40: 2.0, 158: 3.0, 'lane': 0}
# service: {'a_end': 38, 'z_end': 177, 'weight': 1}
# path: {38: 0, 199: 1.0, 239: 2.0, 177: 3.0, 'lane': 0}
# service: {'a_end': 54, 'z_end': 94, 'weight': 4}
# path: {54: 0, 61: 2.0, 49: 3.0, 94: 4.0, 'lane': 2}
# service: {'a_end': 142, 'z_end': 187, 'weight': 1}
# path: {142: 0, 74: 1.0, 40: 2.0, 193: 3.0, 187: 5.0, 'lane': 0}
# service: {'a_end': 152, 'z_end': 50, 'weight': 1}
# path: {152: 0, 177: 1.0, 104: 2.0, 50: 3.0, 'lane': 0}
# service: {'a_end': 170, 'z_end': 85, 'weight': 1}
# path: {170: 0, 131: 1.0, 85: 4.0, 'lane': 0}
# service: {'a_end': 247, 'z_end': 180, 'weight': 1}
# path: {247: 0, 63: 1.0, 54: 3.0, 10: 4.0, 180: 5.0, 'lane': 0}
# service: {'a_end': 175, 'z_end': 222, 'weight': 1}
# path: {175: 0, 135: 1.0, 222: 3.0, 'lane': 0}
# service: {'a_end': 213, 'z_end': 145, 'weight': 1}
# path: {213: 0, 121: 1.0, 91: 2.0, 156: 3.0, 145: 4.0, 'lane': 0}
# service: {'a_end': 130, 'z_end': 146, 'weight': 1}
# path: {130: 0, 197: 2.0, 191: 3.0, 146: 5.0, 'lane': 0}
# service: {'a_end': 141, 'z_end': 18, 'weight': 4}
# path: {141: 0, 18: 2.0, 'lane': 0}
# service: {'a_end': 63, 'z_end': 122, 'weight': 1}
# path: {63: 0, 79: 1.0, 99: 2.0, 123: 3.0, 122: 4.0, 'lane': 0}
# service: {'a_end': 246, 'z_end': 52, 'weight': 1}
# path: {246: 0, 4: 1.0, 5: 2.0, 172: 3.0, 52: 4.0, 'lane': 0}
# service: {'a_end': 153, 'z_end': 75, 'weight': 1}
# path: {153: 0, 75: 2.0, 'lane': 0}
# service: {'a_end': 246, 'z_end': 102, 'weight': 1}
# path: {246: 0, 139: 1.0, 253: 2.0, 102: 4.0, 'lane': 0}
# service: {'a_end': 146, 'z_end': 127, 'weight': 1}
# path: {146: 0, 65: 1.0, 127: 3.0, 'lane': 0}
# service: {'a_end': 227, 'z_end': 82, 'weight': 1}
# path: {227: 0, 107: 1.0, 173: 2.0, 82: 4.0, 'lane': 0}
# service: {'a_end': 166, 'z_end': 182, 'weight': 1}
# path: {166: 0, 41: 1.0, 236: 2.0, 182: 3.0, 'lane': 0}
# service: {'a_end': 6, 'z_end': 30, 'weight': 1}
# path: {6: 0, 64: 1.0, 106: 2.0, 98: 3.0, 96: 4.0, 30: 6.0, 'lane': 0}
# service: {'a_end': 118, 'z_end': 9, 'weight': 1}
# path: {118: 0, 97: 1.0, 9: 3.0, 'lane': 0}
# service: {'a_end': 63, 'z_end': 181, 'weight': 1}
# path: {63: 0, 189: 1.0, 60: 3.0, 181: 4.0, 'lane': 0}
# service: {'a_end': 125, 'z_end': 121, 'weight': 1}
# path: {125: 0, 3: 1.0, 116: 2.0, 213: 3.0, 121: 4.0, 'lane': 0}
# service: {'a_end': 124, 'z_end': 251, 'weight': 1}
# path: {124: 0, 188: 1.0, 251: 3.0, 'lane': 0}
# service: {'a_end': 246, 'z_end': 156, 'weight': 1}
# path: {246: 0, 143: 1.0, 56: 2.0, 156: 3.0, 'lane': 0}
# service: {'a_end': 41, 'z_end': 147, 'weight': 1}
# path: {41: 0, 183: 3.0, 147: 4.0, 'lane': 0}
# service: {'a_end': 192, 'z_end': 146, 'weight': 10}
# path: {192: 0, 243: 1.0, 146: 3.0, 'lane': 0}
# service: {'a_end': 78, 'z_end': 25, 'weight': 1}
# path: {78: 0, 133: 1.0, 25: 2.0, 'lane': 0}
# service: {'a_end': 122, 'z_end': 162, 'weight': 1}
# path: {122: 0, 123: 1.0, 24: 2.0, 162: 3.0, 'lane': 0}
# service: {'a_end': 187, 'z_end': 107, 'weight': 1}
# path: {187: 0, 162: 1.0, 107: 2.0, 'lane': 0}
# service: {'a_end': 45, 'z_end': 35, 'weight': 1}
# path: {45: 0, 110: 2.0, 35: 4.0, 'lane': 0}
# service: {'a_end': 238, 'z_end': 44, 'weight': 1}
# path: {238: 0, 50: 1.0, 104: 2.0, 177: 3.0, 44: 5.0, 'lane': 0}
# service: {'a_end': 22, 'z_end': 0, 'weight': 1}
# path: {22: 0, 11: 1.0, 116: 3.0, 0: 4.0, 'lane': 0}
# service: {'a_end': 175, 'z_end': 75, 'weight': 1}
# path: {175: 0, 117: 1.0, 75: 2.0, 'lane': 0}
# service: {'a_end': 108, 'z_end': 100, 'weight': 1}
# path: {108: 0, 178: 1.0, 85: 3.0, 100: 5.0, 'lane': 0}
# service: {'a_end': 63, 'z_end': 136, 'weight': 1}
# path: {63: 0, 79: 1.0, 50: 2.0, 114: 3.0, 136: 5.0, 'lane': 0}
# service: {'a_end': 173, 'z_end': 219, 'weight': 1}
# path: {173: 0, 7: 2.0, 214: 3.0, 226: 4.0, 219: 5.0, 'lane': 0}
# service: {'a_end': 55, 'z_end': 15, 'weight': 1}
# path: {55: 0, 172: 1.0, 193: 2.0, 187: 4.0, 15: 5.0, 'lane': 0}
# service: {'a_end': 196, 'z_end': 36, 'weight': 1}
# path: {196: 0, 206: 1.0, 110: 2.0, 36: 4.0, 'lane': 0}
# service: {'a_end': 134, 'z_end': 9, 'weight': 4}
# path: {134: 0, 22: 1.0, 184: 2.0, 9: 4.0, 'lane': 0}
# service: {'a_end': 30, 'z_end': 121, 'weight': 1}
# path: {30: 0, 242: 1.0, 180: 2.0, 121: 3.0, 'lane': 0}
# service: {'a_end': 41, 'z_end': 115, 'weight': 1}
# path: {41: 0, 160: 1.0, 164: 2.0, 195: 3.0, 115: 5.0, 'lane': 0}
# service: {'a_end': 27, 'z_end': 4, 'weight': 1}
# path: {27: 0, 11: 1.0, 70: 2.0, 149: 3.0, 82: 4.0, 4: 5.0, 'lane': 0}
# service: {'a_end': 158, 'z_end': 81, 'weight': 1}
# path: {158: 0, 135: 2.0, 230: 3.0, 81: 5.0, 'lane': 0}
# service: {'a_end': 158, 'z_end': 65, 'weight': 1}
# path: {158: 0, 40: 1.0, 154: 2.0, 65: 3.0, 'lane': 0}
# service: {'a_end': 95, 'z_end': 42, 'weight': 1}
# path: {95: 0, 84: 1.0, 90: 2.0, 42: 3.0, 'lane': 0}
# service: {'a_end': 177, 'z_end': 108, 'weight': 1}
# path: {177: 0, 104: 1.0, 50: 2.0, 52: 3.0, 108: 4.0, 'lane': 0}
# service: {'a_end': 236, 'z_end': 20, 'weight': 1}
# path: {236: 0, 105: 1.0, 10: 3.0, 20: 4.0, 'lane': 0}
# service: {'a_end': 240, 'z_end': 40, 'weight': 1}
# path: {240: 0, 158: 2.0, 40: 3.0, 'lane': 0}
# service: {'a_end': 110, 'z_end': 67, 'weight': 1}
# path: {110: 0, 45: 2.0, 72: 3.0, 67: 5.0, 'lane': 0}
# service: {'a_end': 99, 'z_end': 76, 'weight': 1}
# path: {99: 0, 147: 1.0, 128: 3.0, 76: 4.0, 'lane': 0}
# service: {'a_end': 73, 'z_end': 115, 'weight': 1}
# path: {73: 0, 20: 2.0, 115: 3.0, 'lane': 0}
# service: {'a_end': 87, 'z_end': 92, 'weight': 1}
# path: {87: 0, 113: 1.0, 21: 2.0, 92: 3.0, 'lane': 0}
# service: {'a_end': 34, 'z_end': 170, 'weight': 1}
# path: {34: 0, 17: 2.0, 194: 3.0, 170: 4.0, 'lane': 0}
# service: {'a_end': 20, 'z_end': 77, 'weight': 1}
# path: {20: 0, 159: 2.0, 16: 3.0, 77: 4.0, 'lane': 0}
# service: {'a_end': 201, 'z_end': 106, 'weight': 1}
# path: {201: 0, 202: 1.0, 58: 3.0, 106: 4.0, 'lane': 0}
# service: {'a_end': 60, 'z_end': 32, 'weight': 1}
# path: {60: 0, 34: 1.0, 174: 2.0, 32: 4.0, 'lane': 0}
# service: {'a_end': 174, 'z_end': 246, 'weight': 1}
# path: {174: 0, 34: 1.0, 60: 2.0, 46: 3.0, 246: 4.0, 'lane': 0}
# service: {'a_end': 12, 'z_end': 215, 'weight': 1}
# path: {12: 0, 146: 1.0, 65: 2.0, 154: 3.0, 215: 4.0, 'lane': 0}
# service: {'a_end': 167, 'z_end': 28, 'weight': 1}
# path: {167: 0, 42: 1.0, 228: 2.0, 28: 3.0, 'lane': 0}
# service: {'a_end': 108, 'z_end': 202, 'weight': 10}
# path: {108: 0, 62: 1.0, 202: 3.0, 'lane': 1}
# service: {'a_end': 81, 'z_end': 164, 'weight': 1}
# path: {81: 0, 34: 1.0, 161: 2.0, 160: 3.0, 164: 4.0, 'lane': 0}
# service: {'a_end': 220, 'z_end': 96, 'weight': 1}
# path: {220: 0, 246: 1.0, 221: 3.0, 15: 4.0, 96: 5.0, 'lane': 0}
# service: {'a_end': 234, 'z_end': 87, 'weight': 1}
# path: {234: 0, 238: 2.0, 87: 3.0, 'lane': 1}
# service: {'a_end': 204, 'z_end': 239, 'weight': 1}
# path: {204: 0, 30: 1.0, 239: 2.0, 'lane': 0}
# service: {'a_end': 200, 'z_end': 47, 'weight': 4}
# path: {200: 0, 128: 1.0, 76: 2.0, 0: 3.0, 47: 5.0, 'lane': 0}
# service: {'a_end': 115, 'z_end': 173, 'weight': 4}
# path: {115: 0, 7: 1.0, 173: 3.0, 'lane': 0}
# service: {'a_end': 102, 'z_end': 210, 'weight': 1}
# path: {102: 0, 122: 1.0, 170: 2.0, 210: 3.0, 'lane': 0}
# service: {'a_end': 143, 'z_end': 162, 'weight': 1}
# path: {143: 0, 56: 1.0, 107: 2.0, 162: 3.0, 'lane': 0}
# service: {'a_end': 165, 'z_end': 27, 'weight': 1}
# path: {165: 0, 93: 2.0, 167: 3.0, 27: 5.0, 'lane': 0}
# service: {'a_end': 104, 'z_end': 108, 'weight': 1}
# path: {104: 0, 50: 1.0, 52: 2.0, 108: 3.0, 'lane': 0}
# service: {'a_end': 248, 'z_end': 208, 'weight': 1}
# path: {248: 0, 128: 2.0, 225: 3.0, 208: 4.0, 'lane': 0}
# service: {'a_end': 124, 'z_end': 17, 'weight': 1}
# path: {124: 0, 100: 1.0, 174: 2.0, 243: 3.0, 17: 4.0, 'lane': 0}
# service: {'a_end': 101, 'z_end': 102, 'weight': 1}
# path: {101: 0, 118: 2.0, 185: 3.0, 102: 4.0, 'lane': 0}
# service: {'a_end': 197, 'z_end': 176, 'weight': 10}
# path: {197: 0, 229: 1.0, 176: 2.0, 'lane': 1}
# service: {'a_end': 127, 'z_end': 69, 'weight': 1}
# path: {127: 0, 65: 2.0, 223: 3.0, 20: 4.0, 69: 5.0, 'lane': 1}
# service: {'a_end': 106, 'z_end': 246, 'weight': 1}
# path: {106: 0, 64: 1.0, 253: 2.0, 139: 3.0, 246: 4.0, 'lane': 0}
# service: {'a_end': 90, 'z_end': 220, 'weight': 1}
# path: {90: 0, 139: 1.0, 246: 2.0, 220: 3.0, 'lane': 0}
# service: {'a_end': 188, 'z_end': 98, 'weight': 1}
# path: {188: 0, 252: 1.0, 96: 3.0, 98: 4.0, 'lane': 0}
# service: {'a_end': 57, 'z_end': 202, 'weight': 1}
# path: {57: 0, 132: 2.0, 247: 3.0, 202: 4.0, 'lane': 0}
# service: {'a_end': 195, 'z_end': 79, 'weight': 1}
# path: {195: 0, 115: 2.0, 207: 3.0, 79: 5.0, 'lane': 0}
# service: {'a_end': 80, 'z_end': 244, 'weight': 1}
# path: {80: 0, 146: 1.0, 244: 2.0, 'lane': 0}
# service: {'a_end': 30, 'z_end': 234, 'weight': 1}
# path: {30: 0, 204: 1.0, 109: 2.0, 234: 3.0, 'lane': 0}
# service: {'a_end': 27, 'z_end': 135, 'weight': 1}
# path: {27: 0, 231: 2.0, 54: 3.0, 10: 4.0, 135: 5.0, 'lane': 0}
# service: {'a_end': 99, 'z_end': 199, 'weight': 1}
# path: {99: 0, 168: 2.0, 239: 3.0, 199: 4.0, 'lane': 0}
# service: {'a_end': 173, 'z_end': 110, 'weight': 1}
# path: {173: 0, 107: 1.0, 227: 2.0, 136: 3.0, 110: 5.0, 'lane': 0}
# service: {'a_end': 216, 'z_end': 191, 'weight': 1}
# path: {216: 0, 110: 1.0, 136: 3.0, 191: 4.0, 'lane': 0}
# service: {'a_end': 3, 'z_end': 217, 'weight': 1}
# path: {3: 0, 116: 1.0, 69: 2.0, 19: 3.0, 216: 4.0, 217: 5.0, 'lane': 0}
# service: {'a_end': 231, 'z_end': 2, 'weight': 1}
# path: {231: 0, 54: 1.0, 17: 3.0, 2: 4.0, 'lane': 0}
# service: {'a_end': 141, 'z_end': 125, 'weight': 1}
# path: {141: 0, 18: 2.0, 3: 3.0, 125: 4.0, 'lane': 0}
# service: {'a_end': 18, 'z_end': 130, 'weight': 1}
# path: {18: 0, 76: 1.0, 126: 2.0, 130: 4.0, 'lane': 0}
# service: {'a_end': 111, 'z_end': 230, 'weight': 4}
# path: {111: 0, 98: 1.0, 230: 2.0, 'lane': 0}
# service: {'a_end': 46, 'z_end': 11, 'weight': 1}
# path: {46: 0, 60: 1.0, 31: 2.0, 141: 3.0, 11: 4.0, 'lane': 0}
# service: {'a_end': 241, 'z_end': 188, 'weight': 1}
# path: {241: 0, 185: 2.0, 177: 3.0, 188: 5.0, 'lane': 0}
# service: {'a_end': 103, 'z_end': 52, 'weight': 1}
# path: {103: 0, 211: 1.0, 55: 2.0, 172: 3.0, 52: 4.0, 'lane': 0}
# service: {'a_end': 31, 'z_end': 230, 'weight': 1}
# path: {31: 0, 47: 2.0, 230: 3.0, 'lane': 0}
# service: {'a_end': 14, 'z_end': 207, 'weight': 4}
# path: {14: 0, 249: 2.0, 207: 3.0, 'lane': 0}
# service: {'a_end': 89, 'z_end': 178, 'weight': 1}
# path: {89: 0, 128: 1.0, 200: 2.0, 205: 3.0, 178: 4.0, 'lane': 0}
# service: {'a_end': 43, 'z_end': 232, 'weight': 1}
# path: {43: 0, 240: 1.0, 232: 2.0, 'lane': 0}
# service: {'a_end': 126, 'z_end': 87, 'weight': 1}
# path: {126: 0, 76: 1.0, 75: 3.0, 87: 4.0, 'lane': 0}
# service: {'a_end': 135, 'z_end': 152, 'weight': 1}
# path: {135: 0, 175: 1.0, 66: 2.0, 152: 5.0, 'lane': 0}
# service: {'a_end': 169, 'z_end': 84, 'weight': 1}
# path: {169: 0, 225: 1.0, 42: 2.0, 90: 3.0, 84: 4.0, 'lane': 0}
# service: {'a_end': 110, 'z_end': 6, 'weight': 1}
# path: {110: 0, 94: 1.0, 70: 2.0, 149: 3.0, 6: 4.0, 'lane': 0}
# service: {'a_end': 99, 'z_end': 83, 'weight': 1}
# path: {99: 0, 123: 1.0, 83: 2.0, 'lane': 0}
# service: {'a_end': 120, 'z_end': 176, 'weight': 1}
# path: {120: 0, 80: 1.0, 176: 2.0, 'lane': 0}
# service: {'a_end': 121, 'z_end': 109, 'weight': 1}
# path: {121: 0, 117: 1.0, 248: 2.0, 109: 3.0, 'lane': 0}
# service: {'a_end': 21, 'z_end': 35, 'weight': 1}
# path: {21: 0, 120: 1.0, 164: 2.0, 195: 3.0, 35: 4.0, 'lane': 0}
# service: {'a_end': 36, 'z_end': 157, 'weight': 1}
# path: {36: 0, 233: 1.0, 218: 3.0, 157: 4.0, 'lane': 0}
# service: {'a_end': 21, 'z_end': 165, 'weight': 1}
# path: {21: 0, 98: 1.0, 230: 2.0, 47: 3.0, 165: 4.0, 'lane': 0}
# service: {'a_end': 188, 'z_end': 11, 'weight': 1}
# path: {188: 0, 183: 1.0, 79: 2.0, 50: 3.0, 11: 5.0, 'lane': 0}
# service: {'a_end': 186, 'z_end': 161, 'weight': 1}
# path: {186: 0, 50: 1.0, 52: 2.0, 235: 3.0, 161: 4.0, 'lane': 0}
# service: {'a_end': 19, 'z_end': 56, 'weight': 1}
# path: {19: 0, 210: 1.0, 107: 2.0, 56: 3.0, 'lane': 0}
# service: {'a_end': 55, 'z_end': 250, 'weight': 1}
# path: {55: 0, 70: 1.0, 149: 2.0, 250: 3.0, 'lane': 0}
# service: {'a_end': 240, 'z_end': 148, 'weight': 1}
# path: {240: 0, 232: 1.0, 199: 3.0, 148: 4.0, 'lane': 0}
# service: {'a_end': 187, 'z_end': 24, 'weight': 1}
# path: {187: 0, 162: 1.0, 24: 2.0, 'lane': 0}
# service: {'a_end': 2, 'z_end': 209, 'weight': 1}
# path: {2: 0, 65: 1.0, 154: 2.0, 209: 3.0, 'lane': 0}
# service: {'a_end': 111, 'z_end': 218, 'weight': 4}
# path: {111: 0, 98: 1.0, 125: 2.0, 218: 3.0, 'lane': 0}
# service: {'a_end': 234, 'z_end': 127, 'weight': 1}
# path: {234: 0, 109: 1.0, 176: 2.0, 127: 5.0, 'lane': 0}
# service: {'a_end': 184, 'z_end': 197, 'weight': 1}
# path: {184: 0, 166: 1.0, 191: 2.0, 197: 3.0, 'lane': 0}
# service: {'a_end': 84, 'z_end': 141, 'weight': 1}
# path: {84: 0, 90: 1.0, 240: 2.0, 141: 4.0, 'lane': 0}
# service: {'a_end': 212, 'z_end': 237, 'weight': 4}
# path: {212: 0, 137: 1.0, 118: 2.0, 97: 3.0, 237: 5.0, 'lane': 0}
# service: {'a_end': 168, 'z_end': 56, 'weight': 1}
# path: {168: 0, 107: 2.0, 56: 3.0, 'lane': 0}
# service: {'a_end': 245, 'z_end': 225, 'weight': 1}
# path: {245: 0, 180: 1.0, 10: 2.0, 225: 5.0, 'lane': 0}
# service: {'a_end': 210, 'z_end': 216, 'weight': 1}
# path: {210: 0, 19: 1.0, 216: 2.0, 'lane': 0}
# service: {'a_end': 21, 'z_end': 86, 'weight': 1}
# path: {21: 0, 156: 1.0, 86: 3.0, 'lane': 0}
# service: {'a_end': 129, 'z_end': 166, 'weight': 10}
# path: {129: 0, 166: 2.0, 'lane': 1}
# service: {'a_end': 188, 'z_end': 240, 'weight': 1}
# path: {188: 0, 183: 1.0, 240: 3.0, 'lane': 0}
# service: {'a_end': 216, 'z_end': 25, 'weight': 1}
# path: {216: 0, 217: 1.0, 82: 2.0, 4: 3.0, 25: 4.0, 'lane': 0}
# service: {'a_end': 199, 'z_end': 94, 'weight': 1}
# path: {199: 0, 148: 1.0, 215: 3.0, 94: 4.0, 'lane': 0}
# service: {'a_end': 201, 'z_end': 97, 'weight': 1}
# path: {201: 0, 202: 1.0, 228: 2.0, 97: 4.0, 'lane': 0}
# service: {'a_end': 57, 'z_end': 130, 'weight': 1}
# path: {57: 0, 250: 3.0, 130: 4.0, 'lane': 0}
# service: {'a_end': 113, 'z_end': 50, 'weight': 1}
# path: {113: 0, 80: 1.0, 238: 2.0, 50: 3.0, 'lane': 0}
# service: {'a_end': 57, 'z_end': 238, 'weight': 1}
# path: {57: 0, 146: 1.0, 80: 2.0, 238: 3.0, 'lane': 0}
# service: {'a_end': 219, 'z_end': 253, 'weight': 1}
# path: {219: 0, 216: 2.0, 217: 3.0, 253: 5.0, 'lane': 0}
# service: {'a_end': 225, 'z_end': 97, 'weight': 1}
# path: {225: 0, 42: 1.0, 228: 2.0, 97: 4.0, 'lane': 0}
# service: {'a_end': 89, 'z_end': 90, 'weight': 1}
# path: {89: 0, 128: 1.0, 225: 2.0, 42: 3.0, 90: 4.0, 'lane': 1}
# service: {'a_end': 203, 'z_end': 67, 'weight': 4}
# path: {203: 0, 91: 2.0, 156: 3.0, 67: 6.0, 'lane': 0}
# service: {'a_end': 24, 'z_end': 29, 'weight': 10}
# path: {24: 0, 54: 1.0, 29: 2.0, 'lane': 1}
# service: {'a_end': 241, 'z_end': 14, 'weight': 1}
# path: {241: 0, 185: 2.0, 14: 4.0, 'lane': 0}
# service: {'a_end': 101, 'z_end': 24, 'weight': 1}
# path: {101: 0, 38: 1.0, 1: 3.0, 24: 4.0, 'lane': 0}
# service: {'a_end': 164, 'z_end': 243, 'weight': 1}
# path: {164: 0, 160: 1.0, 76: 2.0, 174: 3.0, 243: 4.0, 'lane': 0}
# service: {'a_end': 25, 'z_end': 179, 'weight': 1}
# path: {25: 0, 93: 2.0, 167: 3.0, 179: 4.0, 'lane': 0}
# service: {'a_end': 135, 'z_end': 70, 'weight': 1}
# path: {135: 0, 1: 1.0, 24: 2.0, 181: 3.0, 70: 5.0, 'lane': 0}
# service: {'a_end': 199, 'z_end': 247, 'weight': 1}
# path: {199: 0, 232: 2.0, 132: 3.0, 247: 4.0, 'lane': 0}
# service: {'a_end': 104, 'z_end': 15, 'weight': 4}
# path: {104: 0, 177: 1.0, 185: 2.0, 15: 3.0, 'lane': 0}
# service: {'a_end': 106, 'z_end': 231, 'weight': 1}
# path: {106: 0, 98: 1.0, 111: 2.0, 231: 4.0, 'lane': 0}
# service: {'a_end': 224, 'z_end': 16, 'weight': 1}
# path: {224: 0, 88: 2.0, 159: 4.0, 16: 5.0, 'lane': 0}
# service: {'a_end': 209, 'z_end': 79, 'weight': 10}
# path: {209: 0, 154: 1.0, 65: 2.0, 223: 3.0, 79: 4.0, 'lane': 2}
# service: {'a_end': 211, 'z_end': 6, 'weight': 1}
# path: {211: 0, 64: 3.0, 6: 4.0, 'lane': 0}
# service: {'a_end': 17, 'z_end': 112, 'weight': 4}
# path: {17: 0, 194: 1.0, 113: 2.0, 112: 4.0, 'lane': 0}
# service: {'a_end': 144, 'z_end': 171, 'weight': 1}
# path: {144: 0, 189: 1.0, 155: 2.0, 241: 3.0, 171: 4.0, 'lane': 0}
# service: {'a_end': 116, 'z_end': 219, 'weight': 1}
# path: {116: 0, 0: 1.0, 98: 2.0, 226: 3.0, 219: 4.0, 'lane': 0}
# service: {'a_end': 138, 'z_end': 157, 'weight': 1}
# path: {138: 0, 40: 1.0, 193: 2.0, 157: 3.0, 'lane': 0}
# service: {'a_end': 72, 'z_end': 7, 'weight': 1}
# path: {72: 0, 45: 1.0, 207: 2.0, 115: 3.0, 7: 4.0, 'lane': 0}
# service: {'a_end': 227, 'z_end': 122, 'weight': 1}
# path: {227: 0, 136: 1.0, 122: 4.0, 'lane': 0}
# service: {'a_end': 21, 'z_end': 238, 'weight': 4}
# path: {21: 0, 120: 1.0, 80: 2.0, 238: 3.0, 'lane': 0}
# service: {'a_end': 213, 'z_end': 166, 'weight': 1}
# path: {213: 0, 121: 1.0, 57: 2.0, 194: 3.0, 166: 4.0, 'lane': 0}
# service: {'a_end': 246, 'z_end': 32, 'weight': 1}
# path: {246: 0, 80: 1.0, 113: 2.0, 194: 3.0, 32: 5.0, 'lane': 0}
# service: {'a_end': 76, 'z_end': 250, 'weight': 1}
# path: {76: 0, 126: 1.0, 130: 3.0, 250: 4.0, 'lane': 0}
# service: {'a_end': 142, 'z_end': 1, 'weight': 4}
# path: {142: 0, 74: 1.0, 1: 3.0, 'lane': 0}
# service: {'a_end': 7, 'z_end': 245, 'weight': 1}
# path: {7: 0, 115: 1.0, 234: 2.0, 245: 4.0, 'lane': 0}
# service: {'a_end': 239, 'z_end': 167, 'weight': 1}
# path: {239: 0, 177: 1.0, 167: 4.0, 'lane': 0}
# service: {'a_end': 190, 'z_end': 73, 'weight': 10}
# path: {190: 0, 235: 2.0, 52: 3.0, 73: 5.0, 'lane': 1}
# service: {'a_end': 114, 'z_end': 176, 'weight': 1}
# path: {114: 0, 50: 1.0, 238: 2.0, 80: 3.0, 176: 4.0, 'lane': 0}
# service: {'a_end': 19, 'z_end': 190, 'weight': 10}
# path: {19: 0, 190: 1.0, 'lane': 1}
# service: {'a_end': 201, 'z_end': 212, 'weight': 1}
# path: {201: 0, 56: 1.0, 143: 2.0, 212: 4.0, 'lane': 0}
# service: {'a_end': 210, 'z_end': 241, 'weight': 1}
# path: {210: 0, 55: 1.0, 189: 2.0, 155: 3.0, 241: 4.0, 'lane': 0}
# service: {'a_end': 217, 'z_end': 165, 'weight': 1}
# path: {217: 0, 216: 1.0, 42: 2.0, 230: 3.0, 47: 4.0, 165: 5.0, 'lane': 0}
# service: {'a_end': 209, 'z_end': 230, 'weight': 1}
# path: {209: 0, 111: 2.0, 98: 3.0, 230: 4.0, 'lane': 1}
# service: {'a_end': 23, 'z_end': 52, 'weight': 1}
# path: {23: 0, 87: 1.0, 108: 3.0, 52: 4.0, 'lane': 1}
# service: {'a_end': 173, 'z_end': 37, 'weight': 4}
# path: {173: 0, 248: 1.0, 117: 2.0, 106: 4.0, 37: 5.0, 'lane': 0}
# service: {'a_end': 29, 'z_end': 157, 'weight': 1}
# path: {29: 0, 48: 1.0, 218: 3.0, 157: 4.0, 'lane': 0}
# service: {'a_end': 150, 'z_end': 201, 'weight': 4}
# path: {150: 0, 61: 1.0, 42: 2.0, 228: 3.0, 202: 4.0, 201: 5.0, 'lane': 0}
# service: {'a_end': 126, 'z_end': 204, 'weight': 1}
# path: {126: 0, 204: 1.0, 'lane': 0}
# service: {'a_end': 79, 'z_end': 93, 'weight': 1}
# path: {79: 0, 183: 1.0, 188: 2.0, 93: 4.0, 'lane': 0}
# service: {'a_end': 64, 'z_end': 238, 'weight': 1}
# path: {64: 0, 106: 1.0, 250: 2.0, 87: 3.0, 238: 4.0, 'lane': 1}
# service: {'a_end': 245, 'z_end': 159, 'weight': 1}
# path: {245: 0, 234: 2.0, 227: 3.0, 159: 4.0, 'lane': 0}
# service: {'a_end': 108, 'z_end': 29, 'weight': 1}
# path: {108: 0, 178: 1.0, 175: 3.0, 29: 4.0, 'lane': 0}
# service: {'a_end': 171, 'z_end': 224, 'weight': 1}
# path: {171: 0, 85: 1.0, 71: 2.0, 39: 3.0, 224: 4.0, 'lane': 0}
# service: {'a_end': 109, 'z_end': 147, 'weight': 4}
# path: {109: 0, 202: 1.0, 157: 3.0, 147: 4.0, 'lane': 0}
# service: {'a_end': 196, 'z_end': 116, 'weight': 1}
# path: {196: 0, 206: 1.0, 110: 2.0, 213: 3.0, 116: 4.0, 'lane': 0}
# service: {'a_end': 229, 'z_end': 192, 'weight': 1}
# path: {229: 0, 100: 1.0, 240: 2.0, 192: 4.0, 'lane': 0}
# service: {'a_end': 125, 'z_end': 35, 'weight': 4}
# path: {125: 0, 49: 1.0, 61: 2.0, 35: 3.0, 'lane': 0}
# service: {'a_end': 108, 'z_end': 103, 'weight': 1}
# path: {108: 0, 133: 1.0, 16: 2.0, 159: 3.0, 103: 4.0, 'lane': 1}
# service: {'a_end': 223, 'z_end': 79, 'weight': 1}
# path: {223: 0, 79: 1.0, 'lane': 0}
# service: {'a_end': 23, 'z_end': 240, 'weight': 1}
# path: {23: 0, 202: 1.0, 228: 2.0, 28: 3.0, 240: 4.0, 'lane': 0}
# service: {'a_end': 50, 'z_end': 247, 'weight': 1}
# path: {50: 0, 132: 2.0, 247: 3.0, 'lane': 0}
# service: {'a_end': 141, 'z_end': 125, 'weight': 1}
# path: {141: 0, 18: 2.0, 3: 3.0, 125: 4.0, 'lane': 0}
# service: {'a_end': 67, 'z_end': 180, 'weight': 1}
# path: {67: 0, 245: 2.0, 180: 3.0, 'lane': 0}
# service: {'a_end': 83, 'z_end': 97, 'weight': 4}
# path: {83: 0, 46: 1.0, 237: 2.0, 97: 4.0, 'lane': 0}
# service: {'a_end': 62, 'z_end': 75, 'weight': 10}
# ...
# service: {'a_end': 43, 'z_end': 238, 'weight': 1}
# path: {43: 0, 240: 1.0, 28: 2.0, 238: 4.0, 'lane': 1}
# service: {'a_end': 57, 'z_end': 75, 'weight': 1}
# path: {57: 0, 121: 1.0, 117: 2.0, 75: 3.0, 'lane': 0}
# service: {'a_end': 221, 'z_end': 113, 'weight': 1}
# path: {221: 0, 113: 1.0, 'lane': 0}
# service: {'a_end': 65, 'z_end': 60, 'weight': 1}
# path: {65: 0, 140: 1.0, 59: 2.0, 60: 3.0, 'lane': 1}
# service: {'a_end': 194, 'z_end': 72, 'weight': 1}
# path: {194: 0, 17: 1.0, 45: 2.0, 72: 3.0, 'lane': 0}
# service: {'a_end': 72, 'z_end': 66, 'weight': 1}
# path: {72: 0, 45: 1.0, 11: 2.0, 179: 4.0, 66: 6.0, 'lane': 0}
# service: {'a_end': 22, 'z_end': 239, 'weight': 4}
# path: {22: 0, 184: 1.0, 166: 2.0, 199: 3.0, 239: 4.0, 'lane': 0}
# service: {'a_end': 115, 'z_end': 96, 'weight': 1}
# path: {115: 0, 96: 3.0, 'lane': 0}
# service: {'a_end': 129, 'z_end': 117, 'weight': 1}
# path: {129: 0, 166: 2.0, 229: 4.0, 117: 5.0, 'lane': 0}
# service: {'a_end': 112, 'z_end': 18, 'weight': 1}
# path: {112: 0, 141: 1.0, 18: 3.0, 'lane': 0}
# service: {'a_end': 245, 'z_end': 104, 'weight': 1}
# path: {245: 0, 180: 1.0, 121: 2.0, 46: 4.0, 104: 6.0, 'lane': 0}
# service: {'a_end': 25, 'z_end': 32, 'weight': 1}
# path: {25: 0, 13: 1.0, 126: 2.0, 174: 3.0, 32: 5.0, 'lane': 0}
# service: {'a_end': 180, 'z_end': 124, 'weight': 4}
# path: {180: 0, 10: 1.0, 54: 2.0, 232: 4.0, 124: 5.0, 'lane': 0}
# service: {'a_end': 34, 'z_end': 107, 'weight': 1}
# path: {34: 0, 201: 2.0, 56: 3.0, 107: 4.0, 'lane': 0}
# service: {'a_end': 150, 'z_end': 34, 'weight': 1}
# path: {150: 0, 61: 1.0, 42: 2.0, 38: 3.0, 34: 5.0, 'lane': 0}
# service: {'a_end': 178, 'z_end': 180, 'weight': 1}
# path: {178: 0, 85: 2.0, 121: 4.0, 180: 5.0, 'lane': 0}
# service: {'a_end': 195, 'z_end': 172, 'weight': 1}
# path: {195: 0, 222: 1.0, 4: 2.0, 5: 3.0, 172: 4.0, 'lane': 0}
# service: {'a_end': 21, 'z_end': 20, 'weight': 1}
# path: {21: 0, 156: 1.0, 159: 2.0, 20: 4.0, 'lane': 0}
# service: {'a_end': 188, 'z_end': 95, 'weight': 1}
# path: {188: 0, 252: 1.0, 161: 2.0, 95: 3.0, 'lane': 0}
# service: {'a_end': 206, 'z_end': 82, 'weight': 1}
# path: {206: 0, 108: 1.0, 178: 2.0, 82: 4.0, 'lane': 0}
# service: {'a_end': 43, 'z_end': 122, 'weight': 1}
# path: {43: 0, 83: 1.0, 123: 2.0, 122: 3.0, 'lane': 0}
# service: {'a_end': 58, 'z_end': 231, 'weight': 1}
# path: {58: 0, 16: 1.0, 133: 2.0, 78: 3.0, 231: 4.0, 'lane': 0}
# service: {'a_end': 127, 'z_end': 184, 'weight': 1}
# path: {127: 0, 134: 2.0, 22: 3.0, 184: 4.0, 'lane': 1}
# service: {'a_end': 202, 'z_end': 80, 'weight': 1}
# path: {202: 0, 109: 1.0, 176: 2.0, 80: 3.0, 'lane': 0}
# service: {'a_end': 123, 'z_end': 180, 'weight': 1}
# path: {123: 0, 83: 1.0, 242: 3.0, 180: 4.0, 'lane': 0}
# service: {'a_end': 219, 'z_end': 148, 'weight': 1}
# path: {219: 0, 148: 1.0, 'lane': 1}
# service: {'a_end': 33, 'z_end': 246, 'weight': 1}
# path: {33: 0, 221: 2.0, 246: 4.0, 'lane': 0}
# service: {'a_end': 36, 'z_end': 244, 'weight': 4}
# path: {36: 0, 233: 1.0, 244: 2.0, 'lane': 0}
# service: {'a_end': 114, 'z_end': 179, 'weight': 1}
# path: {114: 0, 53: 2.0, 179: 4.0, 'lane': 0}
# service: {'a_end': 158, 'z_end': 102, 'weight': 1}
# path: {158: 0, 40: 1.0, 145: 2.0, 156: 3.0, 102: 4.0, 'lane': 0}
# service: {'a_end': 136, 'z_end': 116, 'weight': 1}
# path: {136: 0, 69: 1.0, 116: 2.0, 'lane': 0}
# service: {'a_end': 37, 'z_end': 53, 'weight': 1}
# path: {37: 0, 209: 1.0, 154: 2.0, 205: 3.0, 53: 5.0, 'lane': 0}
# service: {'a_end': 243, 'z_end': 193, 'weight': 10}
# path: {243: 0, 55: 1.0, 172: 2.0, 193: 3.0, 'lane': 1}
# service: {'a_end': 115, 'z_end': 207, 'weight': 10}
# path: {115: 0, 207: 1.0, 'lane': 1}
# service: {'a_end': 13, 'z_end': 148, 'weight': 1}
# path: {13: 0, 26: 1.0, 30: 2.0, 148: 3.0, 'lane': 0}
# service: {'a_end': 176, 'z_end': 202, 'weight': 1}
# path: {176: 0, 109: 1.0, 202: 2.0, 'lane': 0}
# service: {'a_end': 129, 'z_end': 22, 'weight': 1}
# path: {129: 0, 166: 2.0, 184: 3.0, 22: 4.0, 'lane': 1}
# service: {'a_end': 37, 'z_end': 60, 'weight': 10}
# path: {37: 0, 181: 1.0, 60: 2.0, 'lane': 2}
# service: {'a_end': 3, 'z_end': 43, 'weight': 10}
# path: {3: 0, 125: 1.0, 43: 2.0, 'lane': 2}
# service: {'a_end': 252, 'z_end': 102, 'weight': 1}
# path: {252: 0, 147: 1.0, 82: 2.0, 149: 3.0, 102: 4.0, 'lane': 0}
# service: {'a_end': 8, 'z_end': 93, 'weight': 1}
# path: {8: 0, 196: 1.0, 93: 3.0, 'lane': 0}
# service: {'a_end': 191, 'z_end': 107, 'weight': 1}
# path: {191: 0, 136: 1.0, 227: 2.0, 107: 3.0, 'lane': 1}
# service: {'a_end': 234, 'z_end': 190, 'weight': 1}
# path: {234: 0, 210: 2.0, 19: 3.0, 190: 4.0, 'lane': 0}
# service: {'a_end': 231, 'z_end': 60, 'weight': 1}
# path: {231: 0, 189: 1.0, 60: 3.0, 'lane': 0}
# service: {'a_end': 159, 'z_end': 104, 'weight': 1}
# path: {159: 0, 103: 1.0, 177: 2.0, 104: 3.0, 'lane': 0}
# service: {'a_end': 11, 'z_end': 224, 'weight': 10}
# path: {11: 0, 141: 1.0, 112: 2.0, 224: 3.0, 'lane': 1}
# service: {'a_end': 62, 'z_end': 124, 'weight': 1}
# path: {62: 0, 220: 1.0, 246: 2.0, 139: 3.0, 124: 5.0, 'lane': 0}
# service: {'a_end': 87, 'z_end': 131, 'weight': 1}
# path: {87: 0, 23: 1.0, 131: 3.0, 'lane': 0}
# service: {'a_end': 207, 'z_end': 46, 'weight': 4}
# path: {207: 0, 114: 1.0, 50: 2.0, 104: 3.0, 46: 5.0, 'lane': 0}
# service: {'a_end': 189, 'z_end': 48, 'weight': 4}
# path: {189: 0, 231: 1.0, 54: 2.0, 29: 3.0, 48: 4.0, 'lane': 0}
# service: {'a_end': 94, 'z_end': 83, 'weight': 1}
# path: {94: 0, 49: 1.0, 125: 2.0, 43: 3.0, 83: 4.0, 'lane': 3}
# service: {'a_end': 164, 'z_end': 52, 'weight': 1}
# path: {164: 0, 218: 2.0, 125: 3.0, 52: 4.0, 'lane': 0}
# service: {'a_end': 212, 'z_end': 97, 'weight': 1}
# path: {212: 0, 137: 1.0, 118: 2.0, 97: 3.0, 'lane': 1}
# service: {'a_end': 38, 'z_end': 191, 'weight': 1}
# path: {38: 0, 199: 1.0, 166: 2.0, 191: 3.0, 'lane': 0}
# service: {'a_end': 81, 'z_end': 112, 'weight': 1}
# path: {81: 0, 34: 1.0, 161: 2.0, 112: 3.0, 'lane': 0}
# service: {'a_end': 74, 'z_end': 35, 'weight': 1}
# path: {74: 0, 192: 1.0, 90: 3.0, 35: 4.0, 'lane': 0}
# service: {'a_end': 38, 'z_end': 92, 'weight': 1}
# path: {38: 0, 137: 1.0, 118: 2.0, 92: 5.0, 'lane': 0}
# service: {'a_end': 29, 'z_end': 77, 'weight': 1}
# path: {29: 0, 48: 1.0, 51: 2.0, 31: 4.0, 77: 5.0, 'lane': 0}
# service: {'a_end': 98, 'z_end': 156, 'weight': 1}
# path: {98: 0, 21: 1.0, 156: 2.0, 'lane': 0}
# service: {'a_end': 132, 'z_end': 124, 'weight': 1}
# path: {132: 0, 232: 1.0, 124: 2.0, 'lane': 0}
# service: {'a_end': 47, 'z_end': 191, 'weight': 1}
# path: {47: 0, 28: 1.0, 12: 2.0, 146: 3.0, 191: 5.0, 'lane': 0}
# service: {'a_end': 201, 'z_end': 101, 'weight': 1}
# path: {201: 0, 56: 1.0, 101: 4.0, 'lane': 0}
# service: {'a_end': 219, 'z_end': 110, 'weight': 1}
# path: {219: 0, 216: 2.0, 110: 3.0, 'lane': 0}
# service: {'a_end': 117, 'z_end': 253, 'weight': 1}
# path: {117: 0, 248: 1.0, 139: 2.0, 253: 3.0, 'lane': 0}
# service: {'a_end': 83, 'z_end': 22, 'weight': 1}
# path: {83: 0, 43: 1.0, 241: 2.0, 134: 4.0, 22: 5.0, 'lane': 0}
# service: {'a_end': 134, 'z_end': 44, 'weight': 1}
# path: {134: 0, 22: 1.0, 11: 2.0, 141: 3.0, 44: 4.0, 'lane': 0}
# service: {'a_end': 82, 'z_end': 121, 'weight': 1}
# path: {82: 0, 4: 1.0, 117: 3.0, 121: 4.0, 'lane': 0}
# service: {'a_end': 88, 'z_end': 185, 'weight': 1}
# path: {88: 0, 221: 1.0, 15: 2.0, 185: 3.0, 'lane': 0}
# service: {'a_end': 45, 'z_end': 47, 'weight': 4}
# path: {45: 0, 13: 1.0, 47: 3.0, 'lane': 0}
# service: {'a_end': 26, 'z_end': 82, 'weight': 1}
# path: {26: 0, 13: 1.0, 25: 2.0, 4: 3.0, 82: 4.0, 'lane': 0}
# service: {'a_end': 224, 'z_end': 112, 'weight': 1}
# path: {224: 0, 112: 1.0, 'lane': 0}
# service: {'a_end': 97, 'z_end': 73, 'weight': 1}
# path: {97: 0, 73: 2.0, 'lane': 0}
# service: {'a_end': 44, 'z_end': 208, 'weight': 1}
# path: {44: 0, 101: 1.0, 208: 2.0, 'lane': 0}
# service: {'a_end': 16, 'z_end': 107, 'weight': 1}
# path: {16: 0, 159: 1.0, 227: 2.0, 107: 3.0, 'lane': 0}
# service: {'a_end': 222, 'z_end': 95, 'weight': 1}
# path: {222: 0, 135: 2.0, 41: 4.0, 95: 5.0, 'lane': 0}
# service: {'a_end': 200, 'z_end': 199, 'weight': 1}
# path: {200: 0, 128: 1.0, 239: 3.0, 199: 4.0, 'lane': 0}
# service: {'a_end': 158, 'z_end': 148, 'weight': 4}
# path: {158: 0, 80: 1.0, 113: 2.0, 219: 3.0, 148: 4.0, 'lane': 1}
# service: {'a_end': 8, 'z_end': 183, 'weight': 1}
# path: {8: 0, 229: 1.0, 100: 2.0, 240: 3.0, 183: 5.0, 'lane': 0}
# service: {'a_end': 21, 'z_end': 147, 'weight': 1}
# path: {21: 0, 120: 1.0, 82: 2.0, 147: 3.0, 'lane': 0}
# service: {'a_end': 137, 'z_end': 57, 'weight': 1}
# path: {137: 0, 212: 1.0, 143: 3.0, 57: 4.0, 'lane': 1}
# service: {'a_end': 224, 'z_end': 13, 'weight': 4}
# path: {224: 0, 92: 1.0, 13: 2.0, 'lane': 0}
# service: {'a_end': 178, 'z_end': 201, 'weight': 1}
# path: {178: 0, 205: 1.0, 154: 2.0, 201: 4.0, 'lane': 0}
# service: {'a_end': 83, 'z_end': 232, 'weight': 1}
# path: {83: 0, 232: 3.0, 'lane': 0}
# service: {'a_end': 68, 'z_end': 116, 'weight': 1}
# path: {68: 0, 28: 1.0, 18: 2.0, 3: 3.0, 116: 4.0, 'lane': 0}
# service: {'a_end': 132, 'z_end': 215, 'weight': 1}
# path: {132: 0, 232: 1.0, 124: 2.0, 215: 4.0, 'lane': 0}
# service: {'a_end': 125, 'z_end': 152, 'weight': 1}
# path: {125: 0, 52: 1.0, 152: 4.0, 'lane': 0}
# service: {'a_end': 25, 'z_end': 226, 'weight': 4}
# path: {25: 0, 13: 1.0, 126: 2.0, 76: 3.0, 226: 4.0, 'lane': 0}
# service: {'a_end': 167, 'z_end': 159, 'weight': 1}
# path: {167: 0, 122: 1.0, 77: 2.0, 16: 3.0, 159: 4.0, 'lane': 0}
# service: {'a_end': 16, 'z_end': 186, 'weight': 1}
# path: {16: 0, 159: 1.0, 227: 2.0, 186: 4.0, 'lane': 1}
# service: {'a_end': 237, 'z_end': 232, 'weight': 1}
# path: {237: 0, 16: 1.0, 58: 2.0, 41: 3.0, 232: 4.0, 'lane': 0}
# service: {'a_end': 140, 'z_end': 81, 'weight': 1}
# path: {140: 0, 59: 1.0, 60: 2.0, 34: 3.0, 81: 4.0, 'lane': 1}
# service: {'a_end': 54, 'z_end': 29, 'weight': 1}
# path: {54: 0, 29: 1.0, 'lane': 0}
# service: {'a_end': 155, 'z_end': 139, 'weight': 1}
# path: {155: 0, 42: 1.0, 90: 2.0, 139: 3.0, 'lane': 1}
# service: {'a_end': 146, 'z_end': 226, 'weight': 1}
# path: {146: 0, 65: 1.0, 214: 3.0, 226: 4.0, 'lane': 0}
# service: {'a_end': 48, 'z_end': 220, 'weight': 1}
# path: {48: 0, 51: 1.0, 146: 2.0, 105: 3.0, 220: 4.0, 'lane': 0}
# service: {'a_end': 232, 'z_end': 104, 'weight': 4}
# path: {232: 0, 124: 1.0, 104: 3.0, 'lane': 1}
# service: {'a_end': 174, 'z_end': 155, 'weight': 1}
# path: {174: 0, 76: 1.0, 160: 2.0, 155: 4.0, 'lane': 0}
# service: {'a_end': 47, 'z_end': 100, 'weight': 1}
# path: {47: 0, 28: 1.0, 240: 2.0, 100: 3.0, 'lane': 1}
# service: {'a_end': 145, 'z_end': 151, 'weight': 1}
# path: {145: 0, 156: 1.0, 102: 2.0, 151: 3.0, 'lane': 0}
# service: {'a_end': 183, 'z_end': 61, 'weight': 1}
# path: {183: 0, 188: 1.0, 251: 3.0, 61: 5.0, 'lane': 0}
# service: {'a_end': 8, 'z_end': 40, 'weight': 1}
# path: {8: 0, 196: 1.0, 158: 3.0, 40: 4.0, 'lane': 0}
# service: {'a_end': 4, 'z_end': 248, 'weight': 4}
# path: {4: 0, 117: 2.0, 248: 3.0, 'lane': 0}
# service: {'a_end': 248, 'z_end': 56, 'weight': 1}
# path: {248: 0, 173: 1.0, 107: 2.0, 56: 3.0, 'lane': 0}
# service: {'a_end': 91, 'z_end': 112, 'weight': 1}
# path: {91: 0, 203: 2.0, 112: 3.0, 'lane': 0}
# service: {'a_end': 21, 'z_end': 199, 'weight': 1}
# path: {21: 0, 113: 1.0, 209: 3.0, 199: 4.0, 'lane': 0}
# service: {'a_end': 138, 'z_end': 161, 'weight': 1}
# path: {138: 0, 90: 1.0, 84: 2.0, 95: 3.0, 161: 4.0, 'lane': 0}
# service: {'a_end': 38, 'z_end': 23, 'weight': 1}
# path: {38: 0, 42: 1.0, 228: 2.0, 202: 3.0, 23: 4.0, 'lane': 0}
# service: {'a_end': 196, 'z_end': 231, 'weight': 1}
# path: {196: 0, 206: 1.0, 235: 4.0, 231: 5.0, 'lane': 0}
# service: {'a_end': 24, 'z_end': 29, 'weight': 10}
# path: {24: 0, 54: 1.0, 29: 2.0, 'lane': 2}
# service: {'a_end': 153, 'z_end': 47, 'weight': 1}
# path: {153: 0, 13: 3.0, 47: 5.0, 'lane': 0}
# service: {'a_end': 242, 'z_end': 156, 'weight': 1}
# path: {242: 0, 30: 1.0, 103: 2.0, 159: 3.0, 156: 4.0, 'lane': 0}
# service: {'a_end': 219, 'z_end': 115, 'weight': 1}
# path: {219: 0, 216: 2.0, 115: 4.0, 'lane': 0}
# service: {'a_end': 217, 'z_end': 131, 'weight': 1}
# path: {217: 0, 193: 2.0, 157: 3.0, 170: 4.0, 131: 5.0, 'lane': 0}
# service: {'a_end': 227, 'z_end': 225, 'weight': 10}
# path: {227: 0, 159: 1.0, 138: 3.0, 225: 4.0, 'lane': 2}
# service: {'a_end': 162, 'z_end': 160, 'weight': 4}
# path: {162: 0, 107: 1.0, 168: 3.0, 160: 5.0, 'lane': 0}
# service: {'a_end': 33, 'z_end': 200, 'weight': 1}
# path: {33: 0, 100: 1.0, 240: 2.0, 183: 4.0, 200: 5.0, 'lane': 0}
# service: {'a_end': 192, 'z_end': 40, 'weight': 1}
# path: {192: 0, 74: 1.0, 40: 2.0, 'lane': 0}
# service: {'a_end': 26, 'z_end': 222, 'weight': 1}
# path: {26: 0, 36: 1.0, 222: 3.0, 'lane': 0}
# service: {'a_end': 175, 'z_end': 210, 'weight': 4}
# path: {175: 0, 20: 1.0, 69: 2.0, 19: 3.0, 210: 4.0, 'lane': 1}
# service: {'a_end': 199, 'z_end': 220, 'weight': 4}
# path: {199: 0, 209: 1.0, 198: 2.0, 220: 4.0, 'lane': 1}
# service: {'a_end': 99, 'z_end': 26, 'weight': 4}
# path: {99: 0, 186: 2.0, 26: 3.0, 'lane': 0}
# service: {'a_end': 80, 'z_end': 148, 'weight': 1}
# path: {80: 0, 113: 1.0, 219: 2.0, 148: 3.0, 'lane': 1}
# service: {'a_end': 134, 'z_end': 215, 'weight': 1}
# path: {134: 0, 223: 2.0, 65: 3.0, 154: 4.0, 215: 5.0, 'lane': 1}
# service: {'a_end': 166, 'z_end': 244, 'weight': 1}
# path: {166: 0, 41: 1.0, 58: 2.0, 244: 3.0, 'lane': 0}
# service: {'a_end': 81, 'z_end': 108, 'weight': 1}
# path: {81: 0, 79: 1.0, 50: 2.0, 52: 3.0, 108: 4.0, 'lane': 0}
# service: {'a_end': 148, 'z_end': 123, 'weight': 1}
# path: {148: 0, 77: 1.0, 122: 2.0, 123: 3.0, 'lane': 0}
# service: {'a_end': 108, 'z_end': 45, 'weight': 1}
# path: {108: 0, 206: 1.0, 110: 2.0, 45: 4.0, 'lane': 0}
# service: {'a_end': 72, 'z_end': 227, 'weight': 1}
# path: {72: 0, 89: 1.0, 186: 2.0, 227: 4.0, 'lane': 1}
# service: {'a_end': 167, 'z_end': 105, 'weight': 1}
# path: {167: 0, 182: 2.0, 236: 3.0, 105: 4.0, 'lane': 0}
# service: {'a_end': 28, 'z_end': 151, 'weight': 1}
# path: {28: 0, 151: 1.0, 'lane': 0}
# service: {'a_end': 178, 'z_end': 89, 'weight': 1}
# path: {178: 0, 205: 1.0, 200: 2.0, 128: 3.0, 89: 4.0, 'lane': 0}
# service: {'a_end': 231, 'z_end': 146, 'weight': 1}
# path: {231: 0, 111: 2.0, 57: 3.0, 146: 4.0, 'lane': 0}
# service: {'a_end': 211, 'z_end': 65, 'weight': 1}
# path: {211: 0, 227: 1.0, 2: 3.0, 65: 4.0, 'lane': 0}
# service: {'a_end': 184, 'z_end': 51, 'weight': 1}
# path: {184: 0, 166: 1.0, 191: 2.0, 146: 4.0, 51: 5.0, 'lane': 0}
# service: {'a_end': 20, 'z_end': 52, 'weight': 1}
# path: {20: 0, 73: 2.0, 52: 4.0, 'lane': 0}
# service: {'a_end': 54, 'z_end': 24, 'weight': 1}
# path: {54: 0, 24: 1.0, 'lane': 0}
# service: {'a_end': 10, 'z_end': 209, 'weight': 1}
# path: {10: 0, 20: 1.0, 214: 2.0, 154: 3.0, 209: 4.0, 'lane': 1}
# service: {'a_end': 99, 'z_end': 58, 'weight': 1}
# path: {99: 0, 159: 2.0, 16: 3.0, 58: 4.0, 'lane': 1}
# service: {'a_end': 85, 'z_end': 73, 'weight': 4}
# path: {85: 0, 171: 1.0, 249: 2.0, 73: 3.0, 'lane': 0}
# service: {'a_end': 248, 'z_end': 171, 'weight': 1}
# path: {248: 0, 139: 1.0, 90: 2.0, 138: 3.0, 171: 4.0, 'lane': 0}
# service: {'a_end': 6, 'z_end': 11, 'weight': 1}
# path: {6: 0, 149: 1.0, 70: 2.0, 11: 3.0, 'lane': 0}
# service: {'a_end': 33, 'z_end': 144, 'weight': 1}
# path: {33: 0, 100: 1.0, 124: 2.0, 144: 5.0, 'lane': 0}
# service: {'a_end': 50, 'z_end': 100, 'weight': 1}
# path: {50: 0, 114: 1.0, 100: 4.0, 'lane': 0}
# service: {'a_end': 52, 'z_end': 93, 'weight': 1}
# path: {52: 0, 73: 2.0, 93: 3.0, 'lane': 0}
# service: {'a_end': 137, 'z_end': 108, 'weight': 1}
# path: {137: 0, 206: 2.0, 108: 3.0, 'lane': 0}
# service: {'a_end': 66, 'z_end': 61, 'weight': 1}
# path: {66: 0, 167: 2.0, 42: 3.0, 61: 4.0, 'lane': 1}
# service: {'a_end': 30, 'z_end': 180, 'weight': 10}
# path: {30: 0, 242: 1.0, 180: 2.0, 'lane': 2}
# service: {'a_end': 122, 'z_end': 195, 'weight': 1}
# path: {122: 0, 123: 1.0, 24: 2.0, 1: 3.0, 195: 4.0, 'lane': 1}
# service: {'a_end': 111, 'z_end': 212, 'weight': 1}
# path: {111: 0, 231: 2.0, 212: 4.0, 'lane': 0}
# service: {'a_end': 93, 'z_end': 130, 'weight': 1}
# path: {93: 0, 167: 1.0, 122: 2.0, 152: 3.0, 130: 4.0, 'lane': 0}
# service: {'a_end': 5, 'z_end': 78, 'weight': 1}
# path: {5: 0, 4: 1.0, 25: 2.0, 133: 3.0, 78: 4.0, 'lane': 0}
# service: {'a_end': 246, 'z_end': 150, 'weight': 1}
# path: {246: 0, 4: 1.0, 203: 3.0, 150: 5.0, 'lane': 0}
# service: {'a_end': 208, 'z_end': 112, 'weight': 1}
# path: {208: 0, 190: 1.0, 112: 4.0, 'lane': 0}
# service: {'a_end': 215, 'z_end': 42, 'weight': 10}
# path: {215: 0, 61: 2.0, 42: 3.0, 'lane': 3}
# 16/09/2021 14:50:36
